# %% [markdown]
# #  Morphological Segmentation with Morfessor (Telugu)
#
# This tutorial demonstrates unsupervised morphological segmentation using **Morfessor** on **Telugu**, a morphologically rich language.
#
# Morfessor breaks words into morphemes (smallest meaning-carrying units) without requiring labeled data — useful for low-resource NLP tasks.
#
# We will:
# - Preprocess Telugu data
# - Train the Morfessor model
# - Predict and visualize segmentations
# - Evaluate segmentation quality

# %%
# !pip install morfessor
import morfessor
import os
# Out:
# Requirement already satisfied: morfessor in c:\users\giridhar kotha\anaconda\lib\site-packages (2.0.6)

# %% [markdown]
# ## 📝 Step 1: Create a Sample Telugu Word File
#
# We'll write a few Telugu words to a `.txt` file — this is needed to train the Morfessor model.

# %%
# Sample Telugu words
telugu_words = [
    "ప్రపంచానికి", "అధ్యాపకుడు", "ఉపాధ్యాయురాలు", "అనుభవించాయి", "చదువుతున్నాను"
]

# Save to file
with open("telugu_sample.txt", "w", encoding="utf-8") as f:
    for word in telugu_words:
        f.write(word + "\n")

print("✅ Wrote Telugu words to telugu_sample.txt")
# Out:
# ✅ Wrote Telugu words to telugu_sample.txt

# %% [markdown]
# ## 🤖 Step 2: Train Morfessor on Telugu Data
# We’ll now train a Morfessor model using the sample Telugu words.

# %%
# Load training data
io = morfessor.MorfessorIO()
data = io.read_corpus_file("telugu_sample.txt")

# Initialize and train the model
model = morfessor.BaselineModel()
model.load_data(data)
model.train_batch()

print("✅ Morfessor training complete!")
# Out:
# 100% (5 of 5) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (5 of 5) |##########################| Elapsed Time: 0:00:00 Time:  0:00:00
# ✅ Morfessor training complete!

# %% [markdown]
# ## 🔍 Step 3: Predict Morpheme Segmentation
#
# Now we’ll test how Morfessor segments some Telugu words.

# %%
# Test words (same ones or new ones)
test_words = [
    "ప్రపంచానికి", "అధ్యాపకుడు", "ఉపాధ్యాయురాలు", "అనుభవించాయి", "చదువుతున్నాను"
]

# Segment and display results
for word in test_words:
    segments = model.viterbi_segment(word)[0]
    print(f"{word} ➝ {' + '.join(segments)}")
# Out:
# ప్రపంచానికి ➝ ప్రపంచానికి
# అధ్యాపకుడు ➝ అధ్యాపకుడు
# ఉపాధ్యాయురాలు ➝ ఉపాధ్యాయురాలు
# అనుభవించాయి ➝ అనుభవించాయి
# చదువుతున్నాను ➝ చదువుతున్నాను

# %%
telugu_words = [
    "చదువుతాడు", "చదువుతున్నారు", "చదువుతున్నాను", "చదువుతుంది", 
    "ఆడుతోంది", "ఆడతాడు", "ఆడారు", "ఆడింది",
    "పరీక్ష", "పరీక్షలకి", "పరీక్షలు", "పరీక్షకు"
]

# %% [markdown]
# ## 📚 Step 4: Train with a Larger Telugu Word List
#
# We’ll now use a longer list of Telugu words that share common patterns (prefixes/suffixes) for better training.

# %%
# Larger word list with repeated roots and suffixes
telugu_words_large = [
    "చదువుతాడు", "చదువుతున్నారు", "చదువుతున్నాను", "చదువుతుంది", "చదువుతుంది",
    "ఆడుతోంది", "ఆడతాడు", "ఆడారు", "ఆడింది", "ఆడుతున్నాడు",
    "పరీక్ష", "పరీక్షలు", "పరీక్షలకి", "పరీక్షలకు", "పరీక్షకు",
    "తెలుగునాడు", "తెలుగులో", "తెలుగువారు", "తెలుగుదేశం", "తెలుగుబడి"
]

# Save to file again (overwrite)
with open("telugu_sample.txt", "w", encoding="utf-8") as f:
    for word in telugu_words_large:
        f.write(word + "\n")

print(f"✅ Wrote {len(telugu_words_large)} Telugu words to telugu_sample.txt")
# Out:
# ✅ Wrote 20 Telugu words to telugu_sample.txt

# %% [markdown]
# ## 🔁 Step 5: Retrain Morfessor with the New Data
# Now we’ll retrain the model using the larger word list.

# %% [markdown]
# # Reload corpus
# data = io.read_corpus_file("telugu_sample.txt")
#
# # Reinitialize model (start fresh)
# model = morfessor.BaselineModel()
# model.load_data(data)
# model.train_batch()
#
# print("✅ Retrained Morfessor with larger dataset!")

# %% [markdown]
# ## 🔄 Step 6: Segment Again Using the Retrained Model
#
# Let’s check if Morfessor now splits words into meaningful morphemes.

# %%
# Predict segmentations on the training words
for word in telugu_words_large:
    segments = model.viterbi_segment(word)[0]
    print(f"{word} ➝ {' + '.join(segments)}")
# Out:
# చదువుతాడు ➝ చదువుతాడు
# చదువుతున్నారు ➝ చదువుతున్నారు
# చదువుతున్నాను ➝ చదువుతున్నాను
# చదువుతుంది ➝ చదువుతుంది
# చదువుతుంది ➝ చదువుతుంది
# ఆడుతోంది ➝ ఆడుతోంది
# ఆడతాడు ➝ ఆడతాడు
# ఆడారు ➝ ఆడారు
# ఆడింది ➝ ఆడింది
# ఆడుతున్నాడు ➝ ఆడుతున్నాడు
# పరీక్ష ➝ పరీక్ష
# పరీక్షలు ➝ పరీక్షలు
# పరీక్షలకి ➝ పరీక్షలకి
# పరీక్షలకు ➝ పరీక్షలకు
# పరీక్షకు ➝ పరీక్షకు
# తెలుగునాడు ➝ తెలుగునాడు
# తెలుగులో ➝ తెలుగులో
# తెలుగువారు ➝ తెలుగువారు
# తెలుగుదేశం ➝ తెలుగుదేశం
# తెలుగుబడి ➝ తెలుగుబడి

# %%
telugu_words_extended = [
    "చదువుతాడు", "చదువుతున్నారు", "చదువుతున్నాను", "చదువుతుంది", "చదువుతున్నవి",
    "పాటలకోసం", "పాటలు", "పాటలతో", "పాటకులకు", "పాటగా",
    "ఆడుతుంది", "ఆడతాడు", "ఆడారు", "ఆడతానని", "ఆడుతున్నాము",
    "పరీక్ష", "పరీక్షలు", "పరీక్షలకి", "పరీక్షలకు", "పరీక్షకు",
    "తెలుగునాడు", "తెలుగులో", "తెలుగువారు", "తెలుగుదేశం", "తెలుగుబడి"
]

# Overwrite file
with open("telugu_sample.txt", "w", encoding="utf-8") as f:
    for word in telugu_words_extended:
        f.write(word + "\n")

print(f"✅ Wrote {len(telugu_words_extended)} words to file")
# Out:
# ✅ Wrote 25 words to file

# %%
# Reload and retrain
data = io.read_corpus_file("telugu_sample.txt")
model = morfessor.BaselineModel()
model.load_data(data)
model.train_batch()

print("🔁 Model retrained on extended data!")
# Out:
# 100% (25 of 25) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (25 of 25) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (25 of 25) |########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 🔁 Model retrained on extended data!

# %%
# Try segmenting again
for word in telugu_words_extended:
    segments = model.viterbi_segment(word)[0]
    print(f"{word} ➝ {' + '.join(segments)}")
# Out:
# చదువుతాడు ➝ చదువుతాడు
# చదువుతున్నారు ➝ చదువుతున్నారు
# చదువుతున్నాను ➝ చదువుతున్నాను
# చదువుతుంది ➝ చదువుతుంది
# చదువుతున్నవి ➝ చదువుతున్నవి
# పాటలకోసం ➝ పాట + లకోసం
# పాటలు ➝ పాట + లు
# పాటలతో ➝ పాట + లతో
# పాటకులకు ➝ పాట + కు + లకు
# పాటగా ➝ పాట + గా
# ఆడుతుంది ➝ ఆడుతుంది
# ఆడతాడు ➝ ఆడతాడు
# ఆడారు ➝ ఆడారు
# ఆడతానని ➝ ఆడతానని
# ఆడుతున్నాము ➝ ఆడుతున్నాము
# పరీక్ష ➝ పరీక్ష
# పరీక్షలు ➝ పరీక్ష + లు
# పరీక్షలకి ➝ పరీక్ష + లకి
# పరీక్షలకు ➝ పరీక్ష + లకు
# పరీక్షకు ➝ పరీక్ష + కు
# తెలుగునాడు ➝ తెలుగునాడు
# తెలుగులో ➝ తెలుగులో
# తెలుగువారు ➝ తెలుగువారు
# తెలుగుదేశం ➝ తెలుగుదేశం
# తెలుగుబడి ➝ తెలుగుబడి

# %%
with open("mixed_telugu_2000.txt", "r", encoding="utf-8") as f:
    train_words = [line.strip() for line in f if line.strip()]

# %%
# Step 2: Initialize and train the Morfessor model
io = morfessor.MorfessorIO()
model = morfessor.BaselineModel()

# Convert words into (count, word) pairs
train_data = [(1, word) for word in train_words]

model.load_data(train_data)
model.train_batch()

print("✅ Morfessor trained on 2000-word mixed dataset.")
# Out:
# 100% (1466 of 1466) |####################| Elapsed Time: 0:00:03 Time:  0:00:03
# 100% (1466 of 1466) |####################| Elapsed Time: 0:00:02 Time:  0:00:02
# 100% (1466 of 1466) |####################| Elapsed Time: 0:00:02 Time:  0:00:02
# 100% (1466 of 1466) |####################| Elapsed Time: 0:00:02 Time:  0:00:02
# 100% (1466 of 1466) |####################| Elapsed Time: 0:00:02 Time:  0:00:02
# 100% (1466 of 1466) |####################| Elapsed Time: 0:00:02 Time:  0:00:02
# ✅ Morfessor trained on 2000-word mixed dataset.

# %%
# Load the 500 test words
with open("telugu_500.txt", "r", encoding="utf-8") as f:
    test_words = [line.strip() for line in f if line.strip()]

# Segment each test word using the trained model
segmented_results = []
for word in test_words:
    segments = model.viterbi_segment(word)[0]
    segmented_results.append(f"{word} ➝ {' + '.join(segments)}")

# Save to a file
with open("final_novel_test_500.txt", "w", encoding="utf-8") as f:
    for line in segmented_results:
        f.write(line + "\n")

print("✅ Segmentation complete. Results saved to segmented_output_500_from_2000mix.txt")
# Out:
# ✅ Segmentation complete. Results saved to segmented_output_500_from_2000mix.txt

# %%
# Count how many words got split (i.e., more than one segment)
split_count = 0

for word in test_words:
    segments = model.viterbi_segment(word)[0]
    if len(segments) > 1:
        split_count += 1

print(f"🔍 {split_count} out of {len(test_words)} words were segmented into multiple morphemes.")
# Out:
# 🔍 461 out of 500 words were segmented into multiple morphemes.

# %%
# Load gold-standard segmentations
with open("Tested500words.txt", "r", encoding="utf-8") as f:
    gold_pairs = [line.strip().split(" ➝ ") for line in f if "➝" in line]

# Create a dictionary from word → correct segmentation
gold_dict = {word: seg.strip() for word, seg in gold_pairs}

# %%
correct = 0
total = len(gold_dict)

print("🔍 Word-by-word comparison:\n")

for word, expected in gold_dict.items():
    predicted = model.viterbi_segment(word)[0]
    match = predicted == expected
    if match:
        correct += 1
    print(f"{word:15} → {' + '.join(predicted):25} | Expected: {' + '.join(expected):25} | {'✅' if match else '❌'}")

accuracy = (correct / total) * 100
print(f"\n📊 Overall Evaluation Accuracy: {accuracy:.2f}% ({correct}/{total} correct)")
# Out:
# 🔍 Word-by-word comparison:
#
# చదువు           → చదువు                     | Expected: చ + ద + ు + వ + ు         | ❌
# మాచదువు         → మాచదువు                   | Expected: మ + ా + చ + ద + ు + వ + ు | ❌
# అచదువు          → అచదువు                    | Expected: అ + చ + ద + ు + వ + ు     | ❌
# ఉపచదువు         → ఉపచదువు                   | Expected: ఉ + ప + చ + ద + ు + వ + ు | ❌
# సహచదువు         → సహచదువు                   | Expected: స + హ + చ + ద + ు + వ + ు | ❌
# చదువుతాడు       → చదువు + తాడు              | Expected: చ + ద + ు + వ + ు + త + ా + డ + ు | ❌
# మాచదువుతాడు     → మాచదువు + తాడు            | Expected: మ + ా + చ + ద + ు + వ + ు +   + + +   + త + ా + డ + ు | ❌
# అచదువుతాడు      → అచదువు + తాడు             | Expected: అ + చ + ద + ు + వ + ు +   + + +   + త + ా + డ + ు | ❌
# ఉపచదువుతాడు     → ఉపచదువు + తాడు            | Expected: ఉ + ప + చ + ద + ు + వ + ు +   + + +   + త + ా + డ + ు | ❌
# సహచదువుతాడు     → సహచదువు + తాడు            | Expected: స + హ + చ + ద + ు + వ + ు +   + + +   + త + ా + డ + ు | ❌
# చదువుతుంది      → చదువు + తుంది             | Expected: చ + ద + ు + వ + ు + త + ు + ం + ద + ి | ❌
# మాచదువుతుంది    → మాచదువు + తుంది           | Expected: మ + ా + చ + ద + ు + వ + ు +   + + +   + త + ు + ం + ద + ి | ❌
# అచదువుతుంది     → అచదువు + తుంది            | Expected: అ + చ + ద + ు + వ + ు +   + + +   + త + ు + ం + ద + ి | ❌
# ఉపచదువుతుంది    → ఉపచదువు + తుంది           | Expected: ఉ + ప + చ + ద + ు + వ + ు +   + + +   + త + ు + ం + ద + ి | ❌
# సహచదువుతుంది    → సహచదువు + తుంది           | Expected: స + హ + చ + ద + ు + వ + ు +   + + +   + త + ు + ం + ద + ి | ❌
# చదువుతున్నారు   → చదువు + తున్నారు          | Expected: చ + ద + ు + వ + ు + త + ు + న + ్ + న + ా + ర + ు | ❌
# మాచదువుతున్నారు → మాచదువు + తున్నారు        | Expected: మ + ా + చ + ద + ు + వ + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# అచదువుతున్నారు  → అచదువు + తున్నారు         | Expected: అ + చ + ద + ు + వ + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# ఉపచదువుతున్నారు → ఉపచదువు + తున్నారు        | Expected: ఉ + ప + చ + ద + ు + వ + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# సహచదువుతున్నారు → సహచదువు + తున్నారు        | Expected: స + హ + చ + ద + ు + వ + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# చదువునాడు       → చదువు + నాడు              | Expected: చ + ద + ు + వ + ు + న + ా + డ + ు | ❌
# మాచదువునాడు     → మాచదువు + నాడు            | Expected: మ + ా + చ + ద + ు + వ + ు +   + + +   + న + ా + డ + ు | ❌
# అచదువునాడు      → అచదువు + నాడు             | Expected: అ + చ + ద + ు + వ + ు +   + + +   + న + ా + డ + ు | ❌
# ఉపచదువునాడు     → ఉపచదువు + నాడు            | Expected: ఉ + ప + చ + ద + ు + వ + ు +   + + +   + న + ా + డ + ు | ❌
# సహచదువునాడు     → సహచదువు + నాడు            | Expected: స + హ + చ + ద + ు + వ + ు +   + + +   + న + ా + డ + ు | ❌
# చదువులు         → చదువు + లు                | Expected: చ + ద + ు + వ + ు + ల + ు | ❌
# మాచదువులు       → మాచదువు + లు              | Expected: మ + ా + చ + ద + ు + వ + ు +   + + +   + ల + ు | ❌
# అచదువులు        → అచదువు + లు               | Expected: అ + చ + ద + ు + వ + ు +   + + +   + ల + ు | ❌
# ఉపచదువులు       → ఉపచదువు + లు              | Expected: ఉ + ప + చ + ద + ు + వ + ు +   + + +   + ల + ు | ❌
# సహచదువులు       → సహచదువు + లు              | Expected: స + హ + చ + ద + ు + వ + ు +   + + +   + ల + ు | ❌
# చదువుకు         → చదువు + కు                | Expected: చ + ద + ు + వ + ు + క + ు | ❌
# మాచదువుకు       → మాచదువు + కు              | Expected: మ + ా + చ + ద + ు + వ + ు +   + + +   + క + ు | ❌
# అచదువుకు        → అచదువు + కు               | Expected: అ + చ + ద + ు + వ + ు +   + + +   + క + ు | ❌
# ఉపచదువుకు       → ఉపచదువు + కు              | Expected: ఉ + ప + చ + ద + ు + వ + ు +   + + +   + క + ు | ❌
# సహచదువుకు       → సహచదువు + కు              | Expected: స + హ + చ + ద + ు + వ + ు +   + + +   + క + ు | ❌
# చదువుగా         → చదువు + గా                | Expected: చ + ద + ు + వ + ు + గ + ా | ❌
# మాచదువుగా       → మాచదువు + గా              | Expected: మ + ా + చ + ద + ు + వ + ు +   + + +   + గ + ా | ❌
# అచదువుగా        → అచదువు + గా               | Expected: అ + చ + ద + ు + వ + ు +   + + +   + గ + ా | ❌
# ఉపచదువుగా       → ఉపచదువు + గా              | Expected: ఉ + ప + చ + ద + ు + వ + ు +   + + +   + గ + ా | ❌
# సహచదువుగా       → సహచదువు + గా              | Expected: స + హ + చ + ద + ు + వ + ు +   + + +   + గ + ా | ❌
# చదువులో         → చదువు + లో                | Expected: చ + ద + ు + వ + ు + ల + ో | ❌
# మాచదువులో       → మాచదువు + లో              | Expected: మ + ా + చ + ద + ు + వ + ు +   + + +   + ల + ో | ❌
# అచదువులో        → అచదువు + లో               | Expected: అ + చ + ద + ు + వ + ు +   + + +   + ల + ో | ❌
# ఉపచదువులో       → ఉపచదువు + లో              | Expected: ఉ + ప + చ + ద + ు + వ + ు +   + + +   + ల + ో | ❌
# సహచదువులో       → సహచదువు + లో              | Expected: స + హ + చ + ద + ు + వ + ు +   + + +   + ల + ో | ❌
# చదువుతో         → చదువు + తో                | Expected: చ + ద + ు + వ + ు + త + ో | ❌
# మాచదువుతో       → మాచదువు + తో              | Expected: మ + ా + చ + ద + ు + వ + ు +   + + +   + త + ో | ❌
# అచదువుతో        → అచదువు + తో               | Expected: అ + చ + ద + ు + వ + ు +   + + +   + త + ో | ❌
# ఉపచదువుతో       → ఉపచదువు + తో              | Expected: ఉ + ప + చ + ద + ు + వ + ు +   + + +   + త + ో | ❌
# సహచదువుతో       → సహచదువు + తో              | Expected: స + హ + చ + ద + ు + వ + ు +   + + +   + త + ో | ❌
# చదువుకి         → చదువు + కి                | Expected: చ + ద + ు + వ + ు + క + ి | ❌
# మాచదువుకి       → మాచదువు + కి              | Expected: మ + ా + చ + ద + ు + వ + ు +   + + +   + క + ి | ❌
# అచదువుకి        → అచదువు + కి               | Expected: అ + చ + ద + ు + వ + ు +   + + +   + క + ి | ❌
# ఉపచదువుకి       → ఉపచదువు + కి              | Expected: ఉ + ప + చ + ద + ు + వ + ు +   + + +   + క + ి | ❌
# సహచదువుకి       → సహచదువు + కి              | Expected: స + హ + చ + ద + ు + వ + ు +   + + +   + క + ి | ❌
# చదువుతోటి       → చదువు + తోటి              | Expected: చ + ద + ు + వ + ు + త + ో +   + + +   + ట + ి | ❌
# మాచదువుతోటి     → మాచదువు + తోటి            | Expected: మ + ా + చ + ద + ు + వ + ు +   + + +   + త + ో +   + + +   + ట + ి | ❌
# అచదువుతోటి      → అచదువు + తోటి             | Expected: అ + చ + ద + ు + వ + ు +   + + +   + త + ో +   + + +   + ట + ి | ❌
# ఉపచదువుతోటి     → ఉపచదువు + తోటి            | Expected: ఉ + ప + చ + ద + ు + వ + ు +   + + +   + త + ో +   + + +   + ట + ి | ❌
# సహచదువుతోటి     → సహచదువు + తోటి            | Expected: స + హ + చ + ద + ు + వ + ు +   + + +   + త + ో +   + + +   + ట + ి | ❌
# మాఆడు           → మాఆడు                     | Expected: మ + ా + ఆ + డ + ు         | ❌
# ఉపఆడు           → ఉపఆడు                     | Expected: ఉ + ప + ఆ + డ + ు         | ❌
# సహఆడు           → సహఆడు                     | Expected: స + హ + ఆ + డ + ు         | ❌
# ఆడుతాడు         → ఆడు + తాడు                | Expected: ఆ + డ + ు + త + ా + డ + ు | ❌
# మాఆడుతాడు       → మాఆడు + తాడు              | Expected: మ + ా + ఆ + డ + ు + త + ా + డ + ు | ❌
# అఆడుతాడు        → అఆడు + తాడు               | Expected: అ + ఆ + డ + ు + త + ా + డ + ు | ❌
# ఉపఆడుతాడు       → ఉపఆడు + తాడు              | Expected: ఉ + ప + ఆ + డ + ు + త + ా + డ + ు | ❌
# సహఆడుతాడు       → సహఆడు + తాడు              | Expected: స + హ + ఆ + డ + ు + త + ా + డ + ు | ❌
# ఆడుతుంది        → ఆడు + తుంది               | Expected: ఆ + డ + ు + త + ు + ం + ద + ి | ❌
# మాఆడుతుంది      → మాఆడు + తుంది             | Expected: మ + ా + ఆ + డ + ు + త + ు + ం + ద + ి | ❌
# అఆడుతుంది       → అఆడు + తుంది              | Expected: అ + ఆ + డ + ు + త + ు + ం + ద + ి | ❌
# ఉపఆడుతుంది      → ఉపఆడు + తుంది             | Expected: ఉ + ప + ఆ + డ + ు + త + ు + ం + ద + ి | ❌
# సహఆడుతుంది      → సహఆడు + తుంది             | Expected: స + హ + ఆ + డ + ు + త + ు + ం + ద + ి | ❌
# ఆడుతున్నారు     → ఆడు + తున్నారు            | Expected: ఆ + డ + ు + త + ు + న + ్ + న + ా + ర + ు | ❌
# మాఆడుతున్నారు   → మాఆడు + తున్నారు          | Expected: మ + ా + ఆ + డ + ు + త + ు + న + ్ + న + ా + ర + ు | ❌
# అఆడుతున్నారు    → అఆడు + తున్నారు           | Expected: అ + ఆ + డ + ు + త + ు + న + ్ + న + ా + ర + ు | ❌
# ఉపఆడుతున్నారు   → ఉపఆడు + తున్నారు          | Expected: ఉ + ప + ఆ + డ + ు + త + ు + న + ్ + న + ా + ర + ు | ❌
# సహఆడుతున్నారు   → సహఆడు + తున్నారు          | Expected: స + హ + ఆ + డ + ు + త + ు + న + ్ + న + ా + ర + ు | ❌
# ఆడునాడు         → ఆడు + నాడు                | Expected: ఆ + డ + ు + న + ా + డ + ు | ❌
# మాఆడునాడు       → మాఆడు + నాడు              | Expected: మ + ా + ఆ + డ + ు + న + ా + డ + ు | ❌
# అఆడునాడు        → అఆడు + నాడు               | Expected: అ + ఆ + డ + ు + న + ా + డ + ు | ❌
# ఉపఆడునాడు       → ఉపఆడు + నాడు              | Expected: ఉ + ప + ఆ + డ + ు + న + ా + డ + ు | ❌
# సహఆడునాడు       → సహఆడు + నాడు              | Expected: స + హ + ఆ + డ + ు + న + ా + డ + ు | ❌
# ఆడులు           → ఆడు + లు                  | Expected: ఆ + డ + ు + ల + ు         | ❌
# మాఆడులు         → మాఆడు + లు                | Expected: మ + ా + ఆ + డ + ు + ల + ు | ❌
# అఆడులు          → అఆడు + లు                 | Expected: అ + ఆ + డ + ు + ల + ు     | ❌
# ఉపఆడులు         → ఉపఆడు + లు                | Expected: ఉ + ప + ఆ + డ + ు + ల + ు | ❌
# సహఆడులు         → సహఆడు + లు                | Expected: స + హ + ఆ + డ + ు + ల + ు | ❌
# ఆడుకు           → ఆడు + కు                  | Expected: ఆ + డ + ు + క + ు         | ❌
# మాఆడుకు         → మాఆడు + కు                | Expected: మ + ా + ఆ + డ + ు + క + ు | ❌
# అఆడుకు          → అఆడు + కు                 | Expected: అ + ఆ + డ + ు + క + ు     | ❌
# ఉపఆడుకు         → ఉపఆడు + కు                | Expected: ఉ + ప + ఆ + డ + ు + క + ు | ❌
# సహఆడుకు         → సహఆడు + కు                | Expected: స + హ + ఆ + డ + ు + క + ు | ❌
# ఆడుగా           → ఆడు + గా                  | Expected: ఆ + డ + ు + గ + ా         | ❌
# మాఆడుగా         → మాఆడు + గా                | Expected: మ + ా + ఆ + డ + ు + గ + ా | ❌
# అఆడుగా          → అఆడు + గా                 | Expected: అ + ఆ + డ + ు + గ + ా     | ❌
# ఉపఆడుగా         → ఉపఆడు + గా                | Expected: ఉ + ప + ఆ + డ + ు + గ + ా | ❌
# సహఆడుగా         → సహఆడు + గా                | Expected: స + హ + ఆ + డ + ు + గ + ా | ❌
# ఆడులో           → ఆడు + లో                  | Expected: ఆ + డ + ు + ల + ో         | ❌
# మాఆడులో         → మాఆడు + లో                | Expected: మ + ా + ఆ + డ + ు + ల + ో | ❌
# అఆడులో          → అఆడు + లో                 | Expected: అ + ఆ + డ + ు + ల + ో     | ❌
# ఉపఆడులో         → ఉపఆడు + లో                | Expected: ఉ + ప + ఆ + డ + ు + ల + ో | ❌
# సహఆడులో         → సహఆడు + లో                | Expected: స + హ + ఆ + డ + ు + ల + ో | ❌
# ఆడుతో           → ఆడు + తో                  | Expected: ఆ + డ + ు + త + ో         | ❌
# మాఆడుతో         → మాఆడు + తో                | Expected: మ + ా + ఆ + డ + ు + త + ో | ❌
# అఆడుతో          → అఆడు + తో                 | Expected: అ + ఆ + డ + ు + త + ో     | ❌
# ఉపఆడుతో         → ఉపఆడు + తో                | Expected: ఉ + ప + ఆ + డ + ు + త + ో | ❌
# సహఆడుతో         → సహఆడు + తో                | Expected: స + హ + ఆ + డ + ు + త + ో | ❌
# ఆడుకి           → ఆడు + కి                  | Expected: ఆ + డ + ు + క + ి         | ❌
# మాఆడుకి         → మాఆడు + కి                | Expected: మ + ా + ఆ + డ + ు + క + ి | ❌
# అఆడుకి          → అఆడు + కి                 | Expected: అ + ఆ + డ + ు + క + ి     | ❌
# ఉపఆడుకి         → ఉపఆడు + కి                | Expected: ఉ + ప + ఆ + డ + ు + క + ి | ❌
# సహఆడుకి         → సహఆడు + కి                | Expected: స + హ + ఆ + డ + ు + క + ి | ❌
# ఆడుతోటి         → ఆడు + తోటి                | Expected: ఆ + డ + ు + త + ో +   + + +   + ట + ి | ❌
# మాఆడుతోటి       → మాఆడు + తోటి              | Expected: మ + ా + ఆ + డ + ు + త + ో +   + + +   + ట + ి | ❌
# అఆడుతోటి        → అఆడు + తోటి               | Expected: అ + ఆ + డ + ు + త + ో +   + + +   + ట + ి | ❌
# ఉపఆడుతోటి       → ఉపఆడు + తోటి              | Expected: ఉ + ప + ఆ + డ + ు + త + ో +   + + +   + ట + ి | ❌
# సహఆడుతోటి       → సహఆడు + తోటి              | Expected: స + హ + ఆ + డ + ు + త + ో +   + + +   + ట + ి | ❌
# పరీక్ష          → పరీక్ష                    | Expected: ప + ర + ీ + క + ్ + ష     | ❌
# మాపరీక్ష        → మాపరీక్ష                  | Expected: మ + ా + ప + ర + ీ + క + ్ + ష | ❌
# అపరీక్ష         → అపరీక్ష                   | Expected: అ + ప + ర + ీ + క + ్ + ష | ❌
# ఉపపరీక్ష        → ఉపపరీక్ష                  | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష | ❌
# సహపరీక్ష        → సహపరీక్ష                  | Expected: స + హ + ప + ర + ీ + క + ్ + ష | ❌
# పరీక్షతాడు      → పరీక్ష + తాడు             | Expected: ప + ర + ీ + క + ్ + ష +   + + +   + త + ా + డ + ు | ❌
# మాపరీక్షతాడు    → మాపరీక్ష + తాడు           | Expected: మ + ా + ప + ర + ీ + క + ్ + ష +   + + +   + త + ా + డ + ు | ❌
# అపరీక్షతాడు     → అపరీక్ష + తాడు            | Expected: అ + ప + ర + ీ + క + ్ + ష +   + + +   + త + ా + డ + ు | ❌
# ఉపపరీక్షతాడు    → ఉపపరీక్ష + తాడు           | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష +   + + +   + త + ా + డ + ు | ❌
# సహపరీక్షతాడు    → సహపరీక్ష + తాడు           | Expected: స + హ + ప + ర + ీ + క + ్ + ష +   + + +   + త + ా + డ + ు | ❌
# పరీక్షతుంది     → పరీక్ష + తుంది            | Expected: ప + ర + ీ + క + ్ + ష +   + + +   + త + ు + ం + ద + ి | ❌
# మాపరీక్షతుంది   → మాపరీక్ష + తుంది          | Expected: మ + ా + ప + ర + ీ + క + ్ + ష +   + + +   + త + ు + ం + ద + ి | ❌
# అపరీక్షతుంది    → అపరీక్ష + తుంది           | Expected: అ + ప + ర + ీ + క + ్ + ష +   + + +   + త + ు + ం + ద + ి | ❌
# ఉపపరీక్షతుంది   → ఉపపరీక్ష + తుంది          | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష +   + + +   + త + ు + ం + ద + ి | ❌
# సహపరీక్షతుంది   → సహపరీక్ష + తుంది          | Expected: స + హ + ప + ర + ీ + క + ్ + ష +   + + +   + త + ు + ం + ద + ి | ❌
# పరీక్షతున్నారు  → పరీక్ష + తున్నారు         | Expected: ప + ర + ీ + క + ్ + ష +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# మాపరీక్షతున్నారు → మాపరీక్ష + తున్నారు       | Expected: మ + ా + ప + ర + ీ + క + ్ + ష +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# అపరీక్షతున్నారు → అపరీక్ష + తున్నారు        | Expected: అ + ప + ర + ీ + క + ్ + ష +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# ఉపపరీక్షతున్నారు → ఉపపరీక్ష + తున్నారు       | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# సహపరీక్షతున్నారు → సహపరీక్ష + తున్నారు       | Expected: స + హ + ప + ర + ీ + క + ్ + ష +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# పరీక్షనాడు      → పరీక్ష + నాడు             | Expected: ప + ర + ీ + క + ్ + ష +   + + +   + న + ా + డ + ు | ❌
# మాపరీక్షనాడు    → మాపరీక్ష + నాడు           | Expected: మ + ా + ప + ర + ీ + క + ్ + ష +   + + +   + న + ా + డ + ు | ❌
# అపరీక్షనాడు     → అపరీక్ష + నాడు            | Expected: అ + ప + ర + ీ + క + ్ + ష +   + + +   + న + ా + డ + ు | ❌
# ఉపపరీక్షనాడు    → ఉపపరీక్ష + నాడు           | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష +   + + +   + న + ా + డ + ు | ❌
# సహపరీక్షనాడు    → సహపరీక్ష + నాడు           | Expected: స + హ + ప + ర + ీ + క + ్ + ష +   + + +   + న + ా + డ + ు | ❌
# పరీక్షలు        → పరీక్ష + లు               | Expected: ప + ర + ీ + క + ్ + ష +   + + +   + ల + ు | ❌
# మాపరీక్షలు      → మాపరీక్ష + లు             | Expected: మ + ా + ప + ర + ీ + క + ్ + ష +   + + +   + ల + ు | ❌
# అపరీక్షలు       → అపరీక్ష + లు              | Expected: అ + ప + ర + ీ + క + ్ + ష +   + + +   + ల + ు | ❌
# ఉపపరీక్షలు      → ఉపపరీక్ష + లు             | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష +   + + +   + ల + ు | ❌
# సహపరీక్షలు      → సహపరీక్ష + లు             | Expected: స + హ + ప + ర + ీ + క + ్ + ష +   + + +   + ల + ు | ❌
# పరీక్షకు        → పరీక్ష + కు               | Expected: ప + ర + ీ + క + ్ + ష +   + + +   + క + ు | ❌
# మాపరీక్షకు      → మాపరీక్ష + కు             | Expected: మ + ా + ప + ర + ీ + క + ్ + ష +   + + +   + క + ు | ❌
# అపరీక్షకు       → అపరీక్ష + కు              | Expected: అ + ప + ర + ీ + క + ్ + ష +   + + +   + క + ు | ❌
# ఉపపరీక్షకు      → ఉపపరీక్ష + కు             | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష +   + + +   + క + ు | ❌
# సహపరీక్షకు      → సహపరీక్ష + కు             | Expected: స + హ + ప + ర + ీ + క + ్ + ష +   + + +   + క + ు | ❌
# పరీక్షగా        → పరీక్ష + గా               | Expected: ప + ర + ీ + క + ్ + ష +   + + +   + గ + ా | ❌
# మాపరీక్షగా      → మాపరీక్ష + గా             | Expected: మ + ా + ప + ర + ీ + క + ్ + ష +   + + +   + గ + ా | ❌
# అపరీక్షగా       → అపరీక్ష + గా              | Expected: అ + ప + ర + ీ + క + ్ + ష +   + + +   + గ + ా | ❌
# ఉపపరీక్షగా      → ఉపపరీక్ష + గా             | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష +   + + +   + గ + ా | ❌
# సహపరీక్షగా      → సహపరీక్ష + గా             | Expected: స + హ + ప + ర + ీ + క + ్ + ష +   + + +   + గ + ా | ❌
# పరీక్షలో        → పరీక్ష + లో               | Expected: ప + ర + ీ + క + ్ + ష +   + + +   + ల + ో | ❌
# మాపరీక్షలో      → మాపరీక్ష + లో             | Expected: మ + ా + ప + ర + ీ + క + ్ + ష +   + + +   + ల + ో | ❌
# అపరీక్షలో       → అపరీక్ష + లో              | Expected: అ + ప + ర + ీ + క + ్ + ష +   + + +   + ల + ో | ❌
# ఉపపరీక్షలో      → ఉపపరీక్ష + లో             | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష +   + + +   + ల + ో | ❌
# సహపరీక్షలో      → సహపరీక్ష + లో             | Expected: స + హ + ప + ర + ీ + క + ్ + ష +   + + +   + ల + ో | ❌
# పరీక్షతో        → పరీక్ష + తో               | Expected: ప + ర + ీ + క + ్ + ష +   + + +   + త + ో | ❌
# మాపరీక్షతో      → మాపరీక్ష + తో             | Expected: మ + ా + ప + ర + ీ + క + ్ + ష +   + + +   + త + ో | ❌
# అపరీక్షతో       → అపరీక్ష + తో              | Expected: అ + ప + ర + ీ + క + ్ + ష +   + + +   + త + ో | ❌
# ఉపపరీక్షతో      → ఉపపరీక్ష + తో             | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష +   + + +   + త + ో | ❌
# సహపరీక్షతో      → సహపరీక్ష + తో             | Expected: స + హ + ప + ర + ీ + క + ్ + ష +   + + +   + త + ో | ❌
# పరీక్షకి        → పరీక్ష + కి               | Expected: ప + ర + ీ + క + ్ + ష +   + + +   + క + ి | ❌
# మాపరీక్షకి      → మాపరీక్ష + కి             | Expected: మ + ా + ప + ర + ీ + క + ్ + ష +   + + +   + క + ి | ❌
# అపరీక్షకి       → అపరీక్ష + కి              | Expected: అ + ప + ర + ీ + క + ్ + ష +   + + +   + క + ి | ❌
# ఉపపరీక్షకి      → ఉపపరీక్ష + కి             | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష +   + + +   + క + ి | ❌
# సహపరీక్షకి      → సహపరీక్ష + కి             | Expected: స + హ + ప + ర + ీ + క + ్ + ష +   + + +   + క + ి | ❌
# పరీక్షతోటి      → పరీక్ష + తోటి             | Expected: ప + ర + ీ + క + ్ + ష +   + + +   + త + ో +   + + +   + ట + ి | ❌
# మాపరీక్షతోటి    → మాపరీక్ష + తోటి           | Expected: మ + ా + ప + ర + ీ + క + ్ + ష +   + + +   + త + ో +   + + +   + ట + ి | ❌
# అపరీక్షతోటి     → అపరీక్ష + తోటి            | Expected: అ + ప + ర + ీ + క + ్ + ష +   + + +   + త + ో +   + + +   + ట + ి | ❌
# ఉపపరీక్షతోటి    → ఉపపరీక్ష + తోటి           | Expected: ఉ + ప + ప + ర + ీ + క + ్ + ష +   + + +   + త + ో +   + + +   + ట + ి | ❌
# సహపరీక్షతోటి    → సహపరీక్ష + తోటి           | Expected: స + హ + ప + ర + ీ + క + ్ + ష +   + + +   + త + ో +   + + +   + ట + ి | ❌
# తెలుగు          → తెలుగు                    | Expected: త + ె + ల + ు + గ + ు     | ❌
# మాతెలుగు        → మాతెలుగు                  | Expected: మ + ా + త + ె + ల + ు + గ + ు | ❌
# అతెలుగు         → అతెలుగు                   | Expected: అ + త + ె + ల + ు + గ + ు | ❌
# ఉపతెలుగు        → ఉపతెలుగు                  | Expected: ఉ + ప + త + ె + ల + ు + గ + ు | ❌
# సహతెలుగు        → సహతెలుగు                  | Expected: స + హ + త + ె + ల + ు + గ + ు | ❌
# తెలుగుతాడు      → తెలుగు + తాడు             | Expected: త + ె + ల + ు + గ + ు +   + + +   + త + ా + డ + ు | ❌
# మాతెలుగుతాడు    → మాతెలుగు + తాడు           | Expected: మ + ా + త + ె + ల + ు + గ + ు +   + + +   + త + ా + డ + ు | ❌
# అతెలుగుతాడు     → అతెలుగు + తాడు            | Expected: అ + త + ె + ల + ు + గ + ు +   + + +   + త + ా + డ + ు | ❌
# ఉపతెలుగుతాడు    → ఉపతెలుగు + తాడు           | Expected: ఉ + ప + త + ె + ల + ు + గ + ు +   + + +   + త + ా + డ + ు | ❌
# సహతెలుగుతాడు    → సహతెలుగు + తాడు           | Expected: స + హ + త + ె + ల + ు + గ + ు +   + + +   + త + ా + డ + ు | ❌
# తెలుగుతుంది     → తెలుగు + తుంది            | Expected: త + ె + ల + ు + గ + ు +   + + +   + త + ు + ం + ద + ి | ❌
# మాతెలుగుతుంది   → మాతెలుగు + తుంది          | Expected: మ + ా + త + ె + ల + ు + గ + ు +   + + +   + త + ు + ం + ద + ి | ❌
# అతెలుగుతుంది    → అతెలుగు + తుంది           | Expected: అ + త + ె + ల + ు + గ + ు +   + + +   + త + ు + ం + ద + ి | ❌
# ఉపతెలుగుతుంది   → ఉపతెలుగు + తుంది          | Expected: ఉ + ప + త + ె + ల + ు + గ + ు +   + + +   + త + ు + ం + ద + ి | ❌
# సహతెలుగుతుంది   → సహతెలుగు + తుంది          | Expected: స + హ + త + ె + ల + ు + గ + ు +   + + +   + త + ు + ం + ద + ి | ❌
# తెలుగుతున్నారు  → తెలుగు + తున్నారు         | Expected: త + ె + ల + ు + గ + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# మాతెలుగుతున్నారు → మాతెలుగు + తున్నారు       | Expected: మ + ా + త + ె + ల + ు + గ + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# అతెలుగుతున్నారు → అతెలుగు + తున్నారు        | Expected: అ + త + ె + ల + ు + గ + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# ఉపతెలుగుతున్నారు → ఉపతెలుగు + తున్నారు       | Expected: ఉ + ప + త + ె + ల + ు + గ + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# సహతెలుగుతున్నారు → సహతెలుగు + తున్నారు       | Expected: స + హ + త + ె + ల + ు + గ + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# తెలుగునాడు      → తెలుగు + నాడు             | Expected: త + ె + ల + ు + గ + ు +   + + +   + న + ా + డ + ు | ❌
# మాతెలుగునాడు    → మాతెలుగు + నాడు           | Expected: మ + ా + త + ె + ల + ు + గ + ు +   + + +   + న + ా + డ + ు | ❌
# అతెలుగునాడు     → అతెలుగు + నాడు            | Expected: అ + త + ె + ల + ు + గ + ు +   + + +   + న + ా + డ + ు | ❌
# ఉపతెలుగునాడు    → ఉపతెలుగు + నాడు           | Expected: ఉ + ప + త + ె + ల + ు + గ + ు +   + + +   + న + ా + డ + ు | ❌
# సహతెలుగునాడు    → సహతెలుగు + నాడు           | Expected: స + హ + త + ె + ల + ు + గ + ు +   + + +   + న + ా + డ + ు | ❌
# తెలుగులు        → తెలుగు + లు               | Expected: త + ె + ల + ు + గ + ు +   + + +   + ల + ు | ❌
# మాతెలుగులు      → మాతెలుగు + లు             | Expected: మ + ా + త + ె + ల + ు + గ + ు +   + + +   + ల + ు | ❌
# అతెలుగులు       → అతెలుగు + లు              | Expected: అ + త + ె + ల + ు + గ + ు +   + + +   + ల + ు | ❌
# ఉపతెలుగులు      → ఉపతెలుగు + లు             | Expected: ఉ + ప + త + ె + ల + ు + గ + ు +   + + +   + ల + ు | ❌
# సహతెలుగులు      → సహతెలుగు + లు             | Expected: స + హ + త + ె + ల + ు + గ + ు +   + + +   + ల + ు | ❌
# తెలుగుకు        → తెలుగు + కు               | Expected: త + ె + ల + ు + గ + ు +   + + +   + క + ు | ❌
# మాతెలుగుకు      → మాతెలుగు + కు             | Expected: మ + ా + త + ె + ల + ు + గ + ు +   + + +   + క + ు | ❌
# అతెలుగుకు       → అతెలుగు + కు              | Expected: అ + త + ె + ల + ు + గ + ు +   + + +   + క + ు | ❌
# ఉపతెలుగుకు      → ఉపతెలుగు + కు             | Expected: ఉ + ప + త + ె + ల + ు + గ + ు +   + + +   + క + ు | ❌
# సహతెలుగుకు      → సహతెలుగు + కు             | Expected: స + హ + త + ె + ల + ు + గ + ు +   + + +   + క + ు | ❌
# తెలుగుగా        → తెలుగు + గా               | Expected: త + ె + ల + ు + గ + ు +   + + +   + గ + ా | ❌
# మాతెలుగుగా      → మాతెలుగు + గా             | Expected: మ + ా + త + ె + ల + ు + గ + ు +   + + +   + గ + ా | ❌
# అతెలుగుగా       → అతెలుగు + గా              | Expected: అ + త + ె + ల + ు + గ + ు +   + + +   + గ + ా | ❌
# ఉపతెలుగుగా      → ఉపతెలుగు + గా             | Expected: ఉ + ప + త + ె + ల + ు + గ + ు +   + + +   + గ + ా | ❌
# సహతెలుగుగా      → సహతెలుగు + గా             | Expected: స + హ + త + ె + ల + ు + గ + ు +   + + +   + గ + ా | ❌
# తెలుగులో        → తెలుగు + లో               | Expected: త + ె + ల + ు + గ + ు +   + + +   + ల + ో | ❌
# మాతెలుగులో      → మాతెలుగు + లో             | Expected: మ + ా + త + ె + ల + ు + గ + ు +   + + +   + ల + ో | ❌
# అతెలుగులో       → అతెలుగు + లో              | Expected: అ + త + ె + ల + ు + గ + ు +   + + +   + ల + ో | ❌
# ఉపతెలుగులో      → ఉపతెలుగు + లో             | Expected: ఉ + ప + త + ె + ల + ు + గ + ు +   + + +   + ల + ో | ❌
# సహతెలుగులో      → సహతెలుగు + లో             | Expected: స + హ + త + ె + ల + ు + గ + ు +   + + +   + ల + ో | ❌
# తెలుగుతో        → తెలుగు + తో               | Expected: త + ె + ల + ు + గ + ు +   + + +   + త + ో | ❌
# మాతెలుగుతో      → మాతెలుగు + తో             | Expected: మ + ా + త + ె + ల + ు + గ + ు +   + + +   + త + ో | ❌
# అతెలుగుతో       → అతెలుగు + తో              | Expected: అ + త + ె + ల + ు + గ + ు +   + + +   + త + ో | ❌
# ఉపతెలుగుతో      → ఉపతెలుగు + తో             | Expected: ఉ + ప + త + ె + ల + ు + గ + ు +   + + +   + త + ో | ❌
# సహతెలుగుతో      → సహతెలుగు + తో             | Expected: స + హ + త + ె + ల + ు + గ + ు +   + + +   + త + ో | ❌
# తెలుగుకి        → తెలుగు + కి               | Expected: త + ె + ల + ు + గ + ు +   + + +   + క + ి | ❌
# మాతెలుగుకి      → మాతెలుగు + కి             | Expected: మ + ా + త + ె + ల + ు + గ + ు +   + + +   + క + ి | ❌
# అతెలుగుకి       → అతెలుగు + కి              | Expected: అ + త + ె + ల + ు + గ + ు +   + + +   + క + ి | ❌
# ఉపతెలుగుకి      → ఉపతెలుగు + కి             | Expected: ఉ + ప + త + ె + ల + ు + గ + ు +   + + +   + క + ి | ❌
# సహతెలుగుకి      → సహతెలుగు + కి             | Expected: స + హ + త + ె + ల + ు + గ + ు +   + + +   + క + ి | ❌
# తెలుగుతోటి      → తెలుగు + తోటి             | Expected: త + ె + ల + ు + గ + ు +   + + +   + త + ో +   + + +   + ట + ి | ❌
# మాతెలుగుతోటి    → మాతెలుగు + తోటి           | Expected: మ + ా + త + ె + ల + ు + గ + ు +   + + +   + త + ో +   + + +   + ట + ి | ❌
# అతెలుగుతోటి     → అతెలుగు + తోటి            | Expected: అ + త + ె + ల + ు + గ + ు +   + + +   + త + ో +   + + +   + ట + ి | ❌
# ఉపతెలుగుతోటి    → ఉపతెలుగు + తోటి           | Expected: ఉ + ప + త + ె + ల + ు + గ + ు +   + + +   + త + ో +   + + +   + ట + ి | ❌
# సహతెలుగుతోటి    → సహతెలుగు + తోటి           | Expected: స + హ + త + ె + ల + ు + గ + ు +   + + +   + త + ో +   + + +   + ట + ి | ❌
# విద్య           → విద్య                     | Expected: వ + ి + ద + ్ + య         | ❌
# మావిద్య         → మావిద్య                   | Expected: మ + ా + వ + ి + ద + ్ + య | ❌
# అవిద్య          → అవిద్య                    | Expected: అ + వ + ి + ద + ్ + య     | ❌
# ఉపవిద్య         → ఉపవిద్య                   | Expected: ఉ + ప + వ + ి + ద + ్ + య | ❌
# సహవిద్య         → సహవిద్య                   | Expected: స + హ + వ + ి + ద + ్ + య | ❌
# విద్యతాడు       → విద్య + తాడు              | Expected: వ + ి + ద + ్ + య + త + ా + డ + ు | ❌
# మావిద్యతాడు     → మావిద్య + తాడు            | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + త + ా + డ + ు | ❌
# అవిద్యతాడు      → అవిద్య + తాడు             | Expected: అ + వ + ి + ద + ్ + య +   + + +   + త + ా + డ + ు | ❌
# ఉపవిద్యతాడు     → ఉపవిద్య + తాడు            | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + త + ా + డ + ు | ❌
# సహవిద్యతాడు     → సహవిద్య + తాడు            | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + త + ా + డ + ు | ❌
# విద్యతుంది      → విద్య + తుంది             | Expected: వ + ి + ద + ్ + య + త + ు + ం + ద + ి | ❌
# మావిద్యతుంది    → మావిద్య + తుంది           | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + త + ు + ం + ద + ి | ❌
# అవిద్యతుంది     → అవిద్య + తుంది            | Expected: అ + వ + ి + ద + ్ + య +   + + +   + త + ు + ం + ద + ి | ❌
# ఉపవిద్యతుంది    → ఉపవిద్య + తుంది           | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + త + ు + ం + ద + ి | ❌
# సహవిద్యతుంది    → సహవిద్య + తుంది           | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + త + ు + ం + ద + ి | ❌
# విద్యతున్నారు   → విద్య + తున్నారు          | Expected: వ + ి + ద + ్ + య + త + ు + న + ్ + న + ా + ర + ు | ❌
# మావిద్యతున్నారు → మావిద్య + తున్నారు        | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# అవిద్యతున్నారు  → అవిద్య + తున్నారు         | Expected: అ + వ + ి + ద + ్ + య +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# ఉపవిద్యతున్నారు → ఉపవిద్య + తున్నారు        | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# సహవిద్యతున్నారు → సహవిద్య + తున్నారు        | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# విద్యనాడు       → విద్య + నాడు              | Expected: వ + ి + ద + ్ + య + న + ా + డ + ు | ❌
# మావిద్యనాడు     → మావిద్య + నాడు            | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + న + ా + డ + ు | ❌
# అవిద్యనాడు      → అవిద్య + నాడు             | Expected: అ + వ + ి + ద + ్ + య +   + + +   + న + ా + డ + ు | ❌
# ఉపవిద్యనాడు     → ఉపవిద్య + నాడు            | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + న + ా + డ + ు | ❌
# సహవిద్యనాడు     → సహవిద్య + నాడు            | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + న + ా + డ + ు | ❌
# విద్యలు         → విద్య + లు                | Expected: వ + ి + ద + ్ + య + ల + ు | ❌
# మావిద్యలు       → మావిద్య + లు              | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ల + ు | ❌
# అవిద్యలు        → అవిద్య + లు               | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ల + ు | ❌
# ఉపవిద్యలు       → ఉపవిద్య + లు              | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ల + ు | ❌
# సహవిద్యలు       → సహవిద్య + లు              | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ల + ు | ❌
# విద్యకు         → విద్య + కు                | Expected: వ + ి + ద + ్ + య + క + ు | ❌
# మావిద్యకు       → మావిద్య + కు              | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + క + ు | ❌
# అవిద్యకు        → అవిద్య + కు               | Expected: అ + వ + ి + ద + ్ + య +   + + +   + క + ు | ❌
# ఉపవిద్యకు       → ఉపవిద్య + కు              | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + క + ు | ❌
# సహవిద్యకు       → సహవిద్య + కు              | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + క + ు | ❌
# విద్యగా         → విద్య + గా                | Expected: వ + ి + ద + ్ + య + గ + ా | ❌
# మావిద్యగా       → మావిద్య + గా              | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + గ + ా | ❌
# అవిద్యగా        → అవిద్య + గా               | Expected: అ + వ + ి + ద + ్ + య +   + + +   + గ + ా | ❌
# ఉపవిద్యగా       → ఉపవిద్య + గా              | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + గ + ా | ❌
# సహవిద్యగా       → సహవిద్య + గా              | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + గ + ా | ❌
# విద్యలో         → విద్య + లో                | Expected: వ + ి + ద + ్ + య + ల + ో | ❌
# మావిద్యలో       → మావిద్య + లో              | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ల + ో | ❌
# అవిద్యలో        → అవిద్య + లో               | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ల + ో | ❌
# ఉపవిద్యలో       → ఉపవిద్య + లో              | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ల + ో | ❌
# సహవిద్యలో       → సహవిద్య + లో              | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ల + ో | ❌
# విద్యతో         → విద్య + తో                | Expected: వ + ి + ద + ్ + య + త + ో | ❌
# మావిద్యతో       → మావిద్య + తో              | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + త + ో | ❌
# అవిద్యతో        → అవిద్య + తో               | Expected: అ + వ + ి + ద + ్ + య +   + + +   + త + ో | ❌
# ఉపవిద్యతో       → ఉపవిద్య + తో              | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + త + ో | ❌
# సహవిద్యతో       → సహవిద్య + తో              | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + త + ో | ❌
# విద్యకి         → విద్య + కి                | Expected: వ + ి + ద + ్ + య + క + ి | ❌
# మావిద్యకి       → మావిద్య + కి              | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + క + ి | ❌
# అవిద్యకి        → అవిద్య + కి               | Expected: అ + వ + ి + ద + ్ + య +   + + +   + క + ి | ❌
# ఉపవిద్యకి       → ఉపవిద్య + కి              | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + క + ి | ❌
# సహవిద్యకి       → సహవిద్య + కి              | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + క + ి | ❌
# విద్యతోటి       → విద్య + తోటి              | Expected: వ + ి + ద + ్ + య + త + ో +   + + +   + ట + ి | ❌
# మావిద్యతోటి     → మావిద్య + తోటి            | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + త + ో +   + + +   + ట + ి | ❌
# అవిద్యతోటి      → అవిద్య + తోటి             | Expected: అ + వ + ి + ద + ్ + య +   + + +   + త + ో +   + + +   + ట + ి | ❌
# ఉపవిద్యతోటి     → ఉపవిద్య + తోటి            | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + త + ో +   + + +   + ట + ి | ❌
# సహవిద్యతోటి     → సహవిద్య + తోటి            | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + త + ో +   + + +   + ట + ి | ❌
# శిక్షణ          → శిక్షణ                    | Expected: శ + ి + క + ్ + ష + ణ     | ❌
# మాశిక్షణ        → మాశిక్షణ                  | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ | ❌
# అశిక్షణ         → అశిక్షణ                   | Expected: అ + శ + ి + క + ్ + ష + ణ | ❌
# ఉపశిక్షణ        → ఉపశిక్షణ                  | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ | ❌
# సహశిక్షణ        → సహశిక్షణ                  | Expected: స + హ + శ + ి + క + ్ + ష + ణ | ❌
# శిక్షణతాడు      → శిక్షణ + తాడు             | Expected: శ + ి + క + ్ + ష + ణ +   + + +   + త + ా + డ + ు | ❌
# మాశిక్షణతాడు    → మాశిక్షణ + తాడు           | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ +   + + +   + త + ా + డ + ు | ❌
# అశిక్షణతాడు     → అశిక్షణ + తాడు            | Expected: అ + శ + ి + క + ్ + ష + ణ +   + + +   + త + ా + డ + ు | ❌
# ఉపశిక్షణతాడు    → ఉపశిక్షణ + తాడు           | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ +   + + +   + త + ా + డ + ు | ❌
# సహశిక్షణతాడు    → సహశిక్షణ + తాడు           | Expected: స + హ + శ + ి + క + ్ + ష + ణ +   + + +   + త + ా + డ + ు | ❌
# శిక్షణతుంది     → శిక్షణ + తుంది            | Expected: శ + ి + క + ్ + ష + ణ +   + + +   + త + ు + ం + ద + ి | ❌
# మాశిక్షణతుంది   → మాశిక్షణ + తుంది          | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ +   + + +   + త + ు + ం + ద + ి | ❌
# అశిక్షణతుంది    → అశిక్షణ + తుంది           | Expected: అ + శ + ి + క + ్ + ష + ణ +   + + +   + త + ు + ం + ద + ి | ❌
# ఉపశిక్షణతుంది   → ఉపశిక్షణ + తుంది          | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ +   + + +   + త + ు + ం + ద + ి | ❌
# సహశిక్షణతుంది   → సహశిక్షణ + తుంది          | Expected: స + హ + శ + ి + క + ్ + ష + ణ +   + + +   + త + ు + ం + ద + ి | ❌
# శిక్షణతున్నారు  → శిక్షణ + తున్నారు         | Expected: శ + ి + క + ్ + ష + ణ +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# మాశిక్షణతున్నారు → మాశిక్షణ + తున్నారు       | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# అశిక్షణతున్నారు → అశిక్షణ + తున్నారు        | Expected: అ + శ + ి + క + ్ + ష + ణ +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# ఉపశిక్షణతున్నారు → ఉపశిక్షణ + తున్నారు       | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# సహశిక్షణతున్నారు → సహశిక్షణ + తున్నారు       | Expected: స + హ + శ + ి + క + ్ + ష + ణ +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# శిక్షణనాడు      → శిక్షణ + నాడు             | Expected: శ + ి + క + ్ + ష + ణ +   + + +   + న + ా + డ + ు | ❌
# మాశిక్షణనాడు    → మాశిక్షణ + నాడు           | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ +   + + +   + న + ా + డ + ు | ❌
# అశిక్షణనాడు     → అశిక్షణ + నాడు            | Expected: అ + శ + ి + క + ్ + ష + ణ +   + + +   + న + ా + డ + ు | ❌
# ఉపశిక్షణనాడు    → ఉపశిక్షణ + నాడు           | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ +   + + +   + న + ా + డ + ు | ❌
# సహశిక్షణనాడు    → సహశిక్షణ + నాడు           | Expected: స + హ + శ + ి + క + ్ + ష + ణ +   + + +   + న + ా + డ + ు | ❌
# శిక్షణలు        → శిక్షణ + లు               | Expected: శ + ి + క + ్ + ష + ణ +   + + +   + ల + ు | ❌
# మాశిక్షణలు      → మాశిక్షణ + లు             | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ +   + + +   + ల + ు | ❌
# అశిక్షణలు       → అశిక్షణ + లు              | Expected: అ + శ + ి + క + ్ + ష + ణ +   + + +   + ల + ు | ❌
# ఉపశిక్షణలు      → ఉపశిక్షణ + లు             | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ +   + + +   + ల + ు | ❌
# సహశిక్షణలు      → సహశిక్షణ + లు             | Expected: స + హ + శ + ి + క + ్ + ష + ణ +   + + +   + ల + ు | ❌
# శిక్షణకు        → శిక్షణ + కు               | Expected: శ + ి + క + ్ + ష + ణ +   + + +   + క + ు | ❌
# మాశిక్షణకు      → మాశిక్షణ + కు             | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ +   + + +   + క + ు | ❌
# అశిక్షణకు       → అశిక్షణ + కు              | Expected: అ + శ + ి + క + ్ + ష + ణ +   + + +   + క + ు | ❌
# ఉపశిక్షణకు      → ఉపశిక్షణ + కు             | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ +   + + +   + క + ు | ❌
# సహశిక్షణకు      → సహశిక్షణ + కు             | Expected: స + హ + శ + ి + క + ్ + ష + ణ +   + + +   + క + ు | ❌
# శిక్షణగా        → శిక్షణ + గా               | Expected: శ + ి + క + ్ + ష + ణ +   + + +   + గ + ా | ❌
# మాశిక్షణగా      → మాశిక్షణ + గా             | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ +   + + +   + గ + ా | ❌
# అశిక్షణగా       → అశిక్షణ + గా              | Expected: అ + శ + ి + క + ్ + ష + ణ +   + + +   + గ + ా | ❌
# ఉపశిక్షణగా      → ఉపశిక్షణ + గా             | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ +   + + +   + గ + ా | ❌
# సహశిక్షణగా      → సహశిక్షణ + గా             | Expected: స + హ + శ + ి + క + ్ + ష + ణ +   + + +   + గ + ా | ❌
# శిక్షణలో        → శిక్షణ + లో               | Expected: శ + ి + క + ్ + ష + ణ +   + + +   + ల + ో | ❌
# మాశిక్షణలో      → మాశిక్షణ + లో             | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ +   + + +   + ల + ో | ❌
# అశిక్షణలో       → అశిక్షణ + లో              | Expected: అ + శ + ి + క + ్ + ష + ణ +   + + +   + ల + ో | ❌
# ఉపశిక్షణలో      → ఉపశిక్షణ + లో             | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ +   + + +   + ల + ో | ❌
# సహశిక్షణలో      → సహశిక్షణ + లో             | Expected: స + హ + శ + ి + క + ్ + ష + ణ +   + + +   + ల + ో | ❌
# శిక్షణతో        → శిక్షణ + తో               | Expected: శ + ి + క + ్ + ష + ణ +   + + +   + త + ో | ❌
# మాశిక్షణతో      → మాశిక్షణ + తో             | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ +   + + +   + త + ో | ❌
# అశిక్షణతో       → అశిక్షణ + తో              | Expected: అ + శ + ి + క + ్ + ష + ణ +   + + +   + త + ో | ❌
# ఉపశిక్షణతో      → ఉపశిక్షణ + తో             | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ +   + + +   + త + ో | ❌
# సహశిక్షణతో      → సహశిక్షణ + తో             | Expected: స + హ + శ + ి + క + ్ + ష + ణ +   + + +   + త + ో | ❌
# శిక్షణకి        → శిక్షణ + కి               | Expected: శ + ి + క + ్ + ష + ణ +   + + +   + క + ి | ❌
# మాశిక్షణకి      → మాశిక్షణ + కి             | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ +   + + +   + క + ి | ❌
# అశిక్షణకి       → అశిక్షణ + కి              | Expected: అ + శ + ి + క + ్ + ష + ణ +   + + +   + క + ి | ❌
# ఉపశిక్షణకి      → ఉపశిక్షణ + కి             | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ +   + + +   + క + ి | ❌
# సహశిక్షణకి      → సహశిక్షణ + కి             | Expected: స + హ + శ + ి + క + ్ + ష + ణ +   + + +   + క + ి | ❌
# శిక్షణతోటి      → శిక్షణ + తోటి             | Expected: శ + ి + క + ్ + ష + ణ +   + + +   + త + ో +   + + +   + ట + ి | ❌
# మాశిక్షణతోటి    → మాశిక్షణ + తోటి           | Expected: మ + ా +   + + +   + శ + ి + క + ్ + ష + ణ +   + + +   + త + ో +   + + +   + ట + ి | ❌
# అశిక్షణతోటి     → అశిక్షణ + తోటి            | Expected: అ + శ + ి + క + ్ + ష + ణ +   + + +   + త + ో +   + + +   + ట + ి | ❌
# ఉపశిక్షణతోటి    → ఉపశిక్షణ + తోటి           | Expected: ఉ + ప + శ + ి + క + ్ + ష + ణ +   + + +   + త + ో +   + + +   + ట + ి | ❌
# సహశిక్షణతోటి    → సహశిక్షణ + తోటి           | Expected: స + హ + శ + ి + క + ్ + ష + ణ +   + + +   + త + ో +   + + +   + ట + ి | ❌
# విద్యార్థి      → విద్యార్థి                | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి | ❌
# మావిద్యార్థి    → మావిద్యార్థి              | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి | ❌
# అవిద్యార్థి     → అవిద్యార్థి               | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి | ❌
# ఉపవిద్యార్థి    → ఉపవిద్యార్థి              | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి | ❌
# సహవిద్యార్థి    → సహ + విద్యార్థి           | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి | ❌
# విద్యార్థితాడు  → విద్యార్థి + తాడు         | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి +   + + +   + త + ా + డ + ు | ❌
# మావిద్యార్థితాడు → మావిద్యార్థి + తాడు       | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ా + డ + ు | ❌
# అవిద్యార్థితాడు → అవిద్యార్థి + తాడు        | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ా + డ + ు | ❌
# ఉపవిద్యార్థితాడు → ఉపవిద్యార్థి + తాడు       | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ా + డ + ు | ❌
# సహవిద్యార్థితాడు → సహ + విద్యార్థి + తాడు    | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ా + డ + ు | ❌
# విద్యార్థితుంది → విద్యార్థి + తుంది        | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి +   + + +   + త + ు + ం + ద + ి | ❌
# మావిద్యార్థితుంది → మావిద్యార్థి + తుంది      | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ు + ం + ద + ి | ❌
# అవిద్యార్థితుంది → అవిద్యార్థి + తుంది       | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ు + ం + ద + ి | ❌
# ఉపవిద్యార్థితుంది → ఉపవిద్యార్థి + తుంది      | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ు + ం + ద + ి | ❌
# సహవిద్యార్థితుంది → సహ + విద్యార్థి + తుంది   | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ు + ం + ద + ి | ❌
# విద్యార్థితున్నారు → విద్యార్థి + తున్నారు     | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# మావిద్యార్థితున్నారు → మావిద్యార్థి + తున్నారు   | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# అవిద్యార్థితున్నారు → అవిద్యార్థి + తున్నారు    | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# ఉపవిద్యార్థితున్నారు → ఉపవిద్యార్థి + తున్నారు   | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# సహవిద్యార్థితున్నారు → సహ + విద్యార్థి + తున్నారు | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# విద్యార్థినాడు  → విద్యార్థి + నాడు         | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి +   + + +   + న + ా + డ + ు | ❌
# మావిద్యార్థినాడు → మావిద్యార్థి + నాడు       | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + న + ా + డ + ు | ❌
# అవిద్యార్థినాడు → అవిద్యార్థి + నాడు        | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + న + ా + డ + ు | ❌
# ఉపవిద్యార్థినాడు → ఉపవిద్యార్థి + నాడు       | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + న + ా + డ + ు | ❌
# సహవిద్యార్థినాడు → సహ + విద్యార్థి + నాడు    | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + న + ా + డ + ు | ❌
# విద్యార్థిలు    → విద్యార్థి + లు           | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి +   + + +   + ల + ు | ❌
# మావిద్యార్థిలు  → మావిద్యార్థి + లు         | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + ల + ు | ❌
# అవిద్యార్థిలు   → అవిద్యార్థి + లు          | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + ల + ు | ❌
# ఉపవిద్యార్థిలు  → ఉపవిద్యార్థి + లు         | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + ల + ు | ❌
# సహవిద్యార్థిలు  → సహ + విద్యార్థి + లు      | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + ల + ు | ❌
# విద్యార్థికు    → విద్యార్థి + కు           | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి +   + + +   + క + ు | ❌
# మావిద్యార్థికు  → మావిద్యార్థి + కు         | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + క + ు | ❌
# అవిద్యార్థికు   → అవిద్యార్థి + కు          | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + క + ు | ❌
# ఉపవిద్యార్థికు  → ఉపవిద్యార్థి + కు         | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + క + ు | ❌
# సహవిద్యార్థికు  → సహ + విద్యార్థి + కు      | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + క + ు | ❌
# విద్యార్థిగా    → విద్యార్థి + గా           | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి +   + + +   + గ + ా | ❌
# మావిద్యార్థిగా  → మావిద్యార్థి + గా         | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + గ + ా | ❌
# అవిద్యార్థిగా   → అవిద్యార్థి + గా          | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + గ + ా | ❌
# ఉపవిద్యార్థిగా  → ఉపవిద్యార్థి + గా         | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + గ + ా | ❌
# సహవిద్యార్థిగా  → సహ + విద్యార్థి + గా      | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + గ + ా | ❌
# విద్యార్థిలో    → విద్యార్థి + లో           | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి +   + + +   + ల + ో | ❌
# మావిద్యార్థిలో  → మావిద్యార్థి + లో         | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + ల + ో | ❌
# అవిద్యార్థిలో   → అవిద్యార్థి + లో          | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + ల + ో | ❌
# ఉపవిద్యార్థిలో  → ఉపవిద్యార్థి + లో         | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + ల + ో | ❌
# సహవిద్యార్థిలో  → సహ + విద్యార్థి + లో      | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + ల + ో | ❌
# విద్యార్థితో    → విద్యార్థి + తో           | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి +   + + +   + త + ో | ❌
# మావిద్యార్థితో  → మావిద్యార్థి + తో         | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ో | ❌
# అవిద్యార్థితో   → అవిద్యార్థి + తో          | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ో | ❌
# ఉపవిద్యార్థితో  → ఉపవిద్యార్థి + తో         | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ో | ❌
# సహవిద్యార్థితో  → సహ + విద్యార్థి + తో      | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + త + ో | ❌
# విద్యార్థికి    → విద్యార్థి + కి           | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి +   + + +   + క + ి | ❌
# మావిద్యార్థికి  → మావిద్యార్థి + కి         | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + క + ి | ❌
# అవిద్యార్థికి   → అవిద్యార్థి + కి          | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + క + ి | ❌
# ఉపవిద్యార్థికి  → ఉపవిద్యార్థి + కి         | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + క + ి | ❌
# సహవిద్యార్థికి  → సహ + విద్యార్థి + కి      | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి +   + + +   + క + ి | ❌
# విద్యార్థితోటి  → విద్యార్థి + తోటి         | Expected: వ + ి + ద + ్ + య + ా + ర + ్ + థ + ి + త + ో + ట + ి | ❌
# మావిద్యార్థితోటి → మావిద్యార్థి + తోటి       | Expected: మ + ా + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి + త + ో + ట + ి | ❌
# అవిద్యార్థితోటి → అవిద్యార్థి + తోటి        | Expected: అ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి + త + ో + ట + ి | ❌
# ఉపవిద్యార్థితోటి → ఉపవిద్యార్థి + తోటి       | Expected: ఉ + ప + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి + త + ో + ట + ి | ❌
# సహవిద్యార్థితోటి → సహ + విద్యార్థి + తోటి    | Expected: స + హ + వ + ి + ద + ్ + య +   + + +   + ా + ర + ్ + థ + ి + త + ో + ట + ి | ❌
# మాగురు          → మాగురు                    | Expected: మ + ా + గ + ు + ర + ు     | ❌
# అగురు           → అగురు                     | Expected: అ + గ + ు + ర + ు         | ❌
# ఉపగురు          → ఉపగురు                    | Expected: ఉ + ప + గ + ు + ర + ు     | ❌
# సహగురు          → సహగురు                    | Expected: స + హ + గ + ు + ర + ు     | ❌
# గురుతాడు        → గురు + తాడు               | Expected: గ + ు + ర + ు +   + + +   + త + ా + డ + ు | ❌
# మాగురుతాడు      → మాగురు + తాడు             | Expected: మ + ా + గ + ు + ర + ు +   + + +   + త + ా + డ + ు | ❌
# అగురుతాడు       → అగురు + తాడు              | Expected: అ + గ + ు + ర + ు +   + + +   + త + ా + డ + ు | ❌
# ఉపగురుతాడు      → ఉపగురు + తాడు             | Expected: ఉ + ప + గ + ు + ర + ు +   + + +   + త + ా + డ + ు | ❌
# సహగురుతాడు      → సహగురు + తాడు             | Expected: స + హ + గ + ు + ర + ు +   + + +   + త + ా + డ + ు | ❌
# గురుతుంది       → గురు + తుంది              | Expected: గ + ు + ర + ు +   + + +   + త + ు + ం + ద + ి | ❌
# మాగురుతుంది     → మాగురు + తుంది            | Expected: మ + ా + గ + ు + ర + ు +   + + +   + త + ు + ం + ద + ి | ❌
# అగురుతుంది      → అగురు + తుంది             | Expected: అ + గ + ు + ర + ు +   + + +   + త + ు + ం + ద + ి | ❌
# ఉపగురుతుంది     → ఉపగురు + తుంది            | Expected: ఉ + ప + గ + ు + ర + ు +   + + +   + త + ు + ం + ద + ి | ❌
# సహగురుతుంది     → సహగురు + తుంది            | Expected: స + హ + గ + ు + ర + ు +   + + +   + త + ు + ం + ద + ి | ❌
# గురుతున్నారు    → గురు + తున్నారు           | Expected: గ + ు + ర + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# మాగురుతున్నారు  → మాగురు + తున్నారు         | Expected: మ + ా + గ + ు + ర + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# అగురుతున్నారు   → అగురు + తున్నారు          | Expected: అ + గ + ు + ర + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# ఉపగురుతున్నారు  → ఉపగురు + తున్నారు         | Expected: ఉ + ప + గ + ు + ర + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# సహగురుతున్నారు  → సహగురు + తున్నారు         | Expected: స + హ + గ + ు + ర + ు +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# గురునాడు        → గురు + నాడు               | Expected: గ + ు + ర + ు +   + + +   + న + ా + డ + ు | ❌
# మాగురునాడు      → మాగురు + నాడు             | Expected: మ + ా + గ + ు + ర + ు +   + + +   + న + ా + డ + ు | ❌
# అగురునాడు       → అగురు + నాడు              | Expected: అ + గ + ు + ర + ు +   + + +   + న + ా + డ + ు | ❌
# ఉపగురునాడు      → ఉపగురు + నాడు             | Expected: ఉ + ప + గ + ు + ర + ు +   + + +   + న + ా + డ + ు | ❌
# సహగురునాడు      → సహగురు + నాడు             | Expected: స + హ + గ + ు + ర + ు +   + + +   + న + ా + డ + ు | ❌
# గురులు          → గురు + లు                 | Expected: గ + ు + ర + ు +   + + +   + ల + ు | ❌
# మాగురులు        → మాగురు + లు               | Expected: మ + ా + గ + ు + ర + ు +   + + +   + ల + ు | ❌
# అగురులు         → అగురు + లు                | Expected: అ + గ + ు + ర + ు +   + + +   + ల + ు | ❌
# ఉపగురులు        → ఉపగురు + లు               | Expected: ఉ + ప + గ + ు + ర + ు +   + + +   + ల + ు | ❌
# సహగురులు        → సహగురు + లు               | Expected: స + హ + గ + ు + ర + ు +   + + +   + ల + ు | ❌
# గురుకు          → గురు + కు                 | Expected: గ + ు + ర + ు +   + + +   + క + ు | ❌
# మాగురుకు        → మాగురు + కు               | Expected: మ + ా + గ + ు + ర + ు +   + + +   + క + ు | ❌
# అగురుకు         → అగురు + కు                | Expected: అ + గ + ు + ర + ు +   + + +   + క + ు | ❌
# ఉపగురుకు        → ఉపగురు + కు               | Expected: ఉ + ప + గ + ు + ర + ు +   + + +   + క + ు | ❌
# సహగురుకు        → సహగురు + కు               | Expected: స + హ + గ + ు + ర + ు +   + + +   + క + ు | ❌
# గురుగా          → గురు + గా                 | Expected: గ + ు + ర + ు +   + + +   + గ + ా | ❌
# మాగురుగా        → మాగురు + గా               | Expected: మ + ా + గ + ు + ర + ు +   + + +   + గ + ా | ❌
# అగురుగా         → అగురు + గా                | Expected: అ + గ + ు + ర + ు +   + + +   + గ + ా | ❌
# ఉపగురుగా        → ఉపగురు + గా               | Expected: ఉ + ప + గ + ు + ర + ు +   + + +   + గ + ా | ❌
# సహగురుగా        → సహగురు + గా               | Expected: స + హ + గ + ు + ర + ు +   + + +   + గ + ా | ❌
# గురులో          → గురు + లో                 | Expected: గ + ు + ర + ు +   + + +   + ల + ో | ❌
# మాగురులో        → మాగురు + లో               | Expected: మ + ా + గ + ు + ర + ు +   + + +   + ల + ో | ❌
# అగురులో         → అగురు + లో                | Expected: అ + గ + ు + ర + ు +   + + +   + ల + ో | ❌
# ఉపగురులో        → ఉపగురు + లో               | Expected: ఉ + ప + గ + ు + ర + ు +   + + +   + ల + ో | ❌
# సహగురులో        → సహగురు + లో               | Expected: స + హ + గ + ు + ర + ు +   + + +   + ల + ో | ❌
# గురుతో          → గురు + తో                 | Expected: గ + ు + ర + ు +   + + +   + త + ో | ❌
# మాగురుతో        → మాగురు + తో               | Expected: మ + ా + గ + ు + ర + ు +   + + +   + త + ో | ❌
# అగురుతో         → అగురు + తో                | Expected: అ + గ + ు + ర + ు +   + + +   + త + ో | ❌
# ఉపగురుతో        → ఉపగురు + తో               | Expected: ఉ + ప + గ + ు + ర + ు +   + + +   + త + ో | ❌
# సహగురుతో        → సహగురు + తో               | Expected: స + హ + గ + ు + ర + ు +   + + +   + త + ో | ❌
# గురుకి          → గురు + కి                 | Expected: గ + ు + ర + ు +   + + +   + క + ి | ❌
# మాగురుకి        → మాగురు + కి               | Expected: మ + ా + గ + ు + ర + ు +   + + +   + క + ి | ❌
# అగురుకి         → అగురు + కి                | Expected: అ + గ + ు + ర + ు +   + + +   + క + ి | ❌
# ఉపగురుకి        → ఉపగురు + కి               | Expected: ఉ + ప + గ + ు + ర + ు +   + + +   + క + ి | ❌
# సహగురుకి        → సహగురు + కి               | Expected: స + హ + గ + ు + ర + ు +   + + +   + క + ి | ❌
# గురుతోటి        → గురు + తోటి               | Expected: గ + ు + ర + ు + త + ో + ట + ి | ❌
# మాగురుతోటి      → మాగురు + తోటి             | Expected: మ + ా + గ + ు + ర + ు + త + ో + ట + ి | ❌
# అగురుతోటి       → అగురు + తోటి              | Expected: అ + గ + ు + ర + ు + త + ో + ట + ి | ❌
# ఉపగురుతోటి      → ఉపగురు + తోటి             | Expected: ఉ + ప + గ + ు + ర + ు + త + ో + ట + ి | ❌
# సహగురుతోటి      → సహగురు + తోటి             | Expected: స + హ + గ + ు + ర + ు + త + ో + ట + ి | ❌
# మాపాఠం          → మాపాఠం                    | Expected: మ + ా + ప + ా + ఠ + ం     | ❌
# అపాఠం           → అపాఠం                     | Expected: అ + ప + ా + ఠ + ం         | ❌
# ఉపపాఠం          → ఉపపాఠం                    | Expected: ఉ + ప + ప + ా + ఠ + ం     | ❌
# సహపాఠం          → సహ + పాఠం                 | Expected: స + హ + ప + ా + ఠ + ం     | ❌
# పాఠంతాడు        → పాఠం + తాడు               | Expected: ప + ా + ఠ + ం +   + + +   + త + ా + డ + ు | ❌
# మాపాఠంతాడు      → మాపాఠం + తాడు             | Expected: మ + ా + ప + ా + ఠ + ం +   + + +   + త + ా + డ + ు | ❌
# అపాఠంతాడు       → అపాఠం + తాడు              | Expected: అ + ప + ా + ఠ + ం +   + + +   + త + ా + డ + ు | ❌
# ఉపపాఠంతాడు      → ఉపపాఠం + తాడు             | Expected: ఉ + ప + ప + ా + ఠ + ం +   + + +   + త + ా + డ + ు | ❌
# సహపాఠంతాడు      → సహ + పాఠం + తాడు          | Expected: స + హ + ప + ా + ఠ + ం +   + + +   + త + ా + డ + ు | ❌
# పాఠంతుంది       → పాఠం + తుంది              | Expected: ప + ా + ఠ + ం +   + + +   + త + ు + ం + ద + ి | ❌
# మాపాఠంతుంది     → మాపాఠం + తుంది            | Expected: మ + ా + ప + ా + ఠ + ం +   + + +   + త + ు + ం + ద + ి | ❌
# అపాఠంతుంది      → అపాఠం + తుంది             | Expected: అ + ప + ా + ఠ + ం +   + + +   + త + ు + ం + ద + ి | ❌
# ఉపపాఠంతుంది     → ఉపపాఠం + తుంది            | Expected: ఉ + ప + ప + ా + ఠ + ం +   + + +   + త + ు + ం + ద + ి | ❌
# సహపాఠంతుంది     → సహ + పాఠం + తుంది         | Expected: స + హ + ప + ా + ఠ + ం +   + + +   + త + ు + ం + ద + ి | ❌
# పాఠంతున్నారు    → పాఠం + తున్నారు           | Expected: ప + ా + ఠ + ం +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# మాపాఠంతున్నారు  → మాపాఠం + తున్నారు         | Expected: మ + ా + ప + ా + ఠ + ం +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# అపాఠంతున్నారు   → అపాఠం + తున్నారు          | Expected: అ + ప + ా + ఠ + ం +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# ఉపపాఠంతున్నారు  → ఉపపాఠం + తున్నారు         | Expected: ఉ + ప + ప + ా + ఠ + ం +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# సహపాఠంతున్నారు  → సహ + పాఠం + తున్నారు      | Expected: స + హ + ప + ా + ఠ + ం +   + + +   + త + ు + న + ్ + న + ా + ర + ు | ❌
# పాఠంనాడు        → పాఠం + నాడు               | Expected: ప + ా + ఠ + ం +   + + +   + న + ా + డ + ు | ❌
# మాపాఠంనాడు      → మాపాఠం + నాడు             | Expected: మ + ా + ప + ా + ఠ + ం +   + + +   + న + ా + డ + ు | ❌
# అపాఠంనాడు       → అపాఠం + నాడు              | Expected: అ + ప + ా + ఠ + ం +   + + +   + న + ా + డ + ు | ❌
# ఉపపాఠంనాడు      → ఉపపాఠం + నాడు             | Expected: ఉ + ప + ప + ా + ఠ + ం +   + + +   + న + ా + డ + ు | ❌
#
# 📊 Overall Evaluation Accuracy: 0.00% (0/500 correct)
