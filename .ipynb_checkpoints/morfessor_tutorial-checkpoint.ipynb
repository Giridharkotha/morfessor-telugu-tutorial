# %% [markdown]
# # 🧠 Morphological Segmentation with Morfessor (Telugu)
#
# This tutorial demonstrates unsupervised morphological segmentation using **Morfessor** on **Telugu**, a morphologically rich language.
#
# Morfessor breaks words into morphemes (smallest meaning-carrying units) without requiring labeled data — useful for low-resource NLP tasks.
#
# We will:
# - Preprocess Telugu data
# - Train the Morfessor model
# - Predict and visualize segmentations
# - Evaluate segmentation quality

# %%
# !pip install morfessor
import morfessor
import os
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: morfessor in c:\users\ual-laptop\appdata\roaming\python\python312\site-packages (2.0.6)

# %% [markdown]
# ## 📝 Step 1: Create a Sample Telugu Word File
#
# We'll write a few Telugu words to a `.txt` file — this is needed to train the Morfessor model.

# %%
# Sample Telugu words
telugu_words = [
    "ప్రపంచానికి", "అధ్యాపకుడు", "ఉపాధ్యాయురాలు", "అనుభవించాయి", "చదువుతున్నాను"
]

# Save to file
with open("telugu_sample.txt", "w", encoding="utf-8") as f:
    for word in telugu_words:
        f.write(word + "\n")

print("✅ Wrote Telugu words to telugu_sample.txt")
# Out:
# ✅ Wrote Telugu words to telugu_sample.txt

# %% [markdown]
# ## 🤖 Step 2: Train Morfessor on Telugu Data
# We’ll now train a Morfessor model using the sample Telugu words.

# %%
# Load training data
io = morfessor.MorfessorIO()
data = io.read_corpus_file("telugu_sample.txt")

# Initialize and train the model
model = morfessor.BaselineModel()
model.load_data(data)
model.train_batch()

print("✅ Morfessor training complete!")
# Out:
# ......
# ......
# ✅ Morfessor training complete!

# %% [markdown]
# ## 🔍 Step 3: Predict Morpheme Segmentation
#
# Now we’ll test how Morfessor segments some Telugu words.

# %%
# Test words (same ones or new ones)
test_words = [
    "ప్రపంచానికి", "అధ్యాపకుడు", "ఉపాధ్యాయురాలు", "అనుభవించాయి", "చదువుతున్నాను"
]

# Segment and display results
for word in test_words:
    segments = model.viterbi_segment(word)[0]
    print(f"{word} ➝ {' + '.join(segments)}")
# Out:
# ప్రపంచానికి ➝ ప్రపంచానికి
# అధ్యాపకుడు ➝ అధ్యాపకుడు
# ఉపాధ్యాయురాలు ➝ ఉపాధ్యాయురాలు
# అనుభవించాయి ➝ అనుభవించాయి
# చదువుతున్నాను ➝ చదువుతున్నాను

# %%
telugu_words = [
    "చదువుతాడు", "చదువుతున్నారు", "చదువుతున్నాను", "చదువుతుంది", 
    "ఆడుతోంది", "ఆడతాడు", "ఆడారు", "ఆడింది",
    "పరీక్ష", "పరీక్షలకి", "పరీక్షలు", "పరీక్షకు"
]

# %% [markdown]
# ## 📚 Step 4: Train with a Larger Telugu Word List
#
# We’ll now use a longer list of Telugu words that share common patterns (prefixes/suffixes) for better training.

# %%
# Larger word list with repeated roots and suffixes
telugu_words_large = [
    "చదువుతాడు", "చదువుతున్నారు", "చదువుతున్నాను", "చదువుతుంది", "చదువుతుంది",
    "ఆడుతోంది", "ఆడతాడు", "ఆడారు", "ఆడింది", "ఆడుతున్నాడు",
    "పరీక్ష", "పరీక్షలు", "పరీక్షలకి", "పరీక్షలకు", "పరీక్షకు",
    "తెలుగునాడు", "తెలుగులో", "తెలుగువారు", "తెలుగుదేశం", "తెలుగుబడి"
]

# Save to file again (overwrite)
with open("telugu_sample.txt", "w", encoding="utf-8") as f:
    for word in telugu_words_large:
        f.write(word + "\n")

print(f"✅ Wrote {len(telugu_words_large)} Telugu words to telugu_sample.txt")
# Out:
# ✅ Wrote 20 Telugu words to telugu_sample.txt

# %% [markdown]
# ## 🔁 Step 5: Retrain Morfessor with the New Data
# Now we’ll retrain the model using the larger word list.

# %% [markdown]
# # Reload corpus
# data = io.read_corpus_file("telugu_sample.txt")
#
# # Reinitialize model (start fresh)
# model = morfessor.BaselineModel()
# model.load_data(data)
# model.train_batch()
#
# print("✅ Retrained Morfessor with larger dataset!")

# %% [markdown]
# ## 🔄 Step 6: Segment Again Using the Retrained Model
#
# Let’s check if Morfessor now splits words into meaningful morphemes.

# %%
# Predict segmentations on the training words
for word in telugu_words_large:
    segments = model.viterbi_segment(word)[0]
    print(f"{word} ➝ {' + '.join(segments)}")
# Out:
# చదువుతాడు ➝ చదువుతాడు
# చదువుతున్నారు ➝ చదువుతున్నారు
# చదువుతున్నాను ➝ చదువుతున్నాను
# చదువుతుంది ➝ చదువుతుంది
# చదువుతుంది ➝ చదువుతుంది
# ఆడుతోంది ➝ ఆడుతోంది
# ఆడతాడు ➝ ఆడతాడు
# ఆడారు ➝ ఆడారు
# ఆడింది ➝ ఆడింది
# ఆడుతున్నాడు ➝ ఆడుతున్నాడు
# పరీక్ష ➝ పరీక్ష
# పరీక్షలు ➝ పరీక్షలు
# పరీక్షలకి ➝ పరీక్షలకి
# పరీక్షలకు ➝ పరీక్షలకు
# పరీక్షకు ➝ పరీక్షకు
# తెలుగునాడు ➝ తెలుగునాడు
# తెలుగులో ➝ తెలుగులో
# తెలుగువారు ➝ తెలుగువారు
# తెలుగుదేశం ➝ తెలుగుదేశం
# తెలుగుబడి ➝ తెలుగుబడి

# %%
telugu_words_extended = [
    "చదువుతాడు", "చదువుతున్నారు", "చదువుతున్నాను", "చదువుతుంది", "చదువుతున్నవి",
    "పాటలకోసం", "పాటలు", "పాటలతో", "పాటకులకు", "పాటగా",
    "ఆడుతుంది", "ఆడతాడు", "ఆడారు", "ఆడతానని", "ఆడుతున్నాము",
    "పరీక్ష", "పరీక్షలు", "పరీక్షలకి", "పరీక్షలకు", "పరీక్షకు",
    "తెలుగునాడు", "తెలుగులో", "తెలుగువారు", "తెలుగుదేశం", "తెలుగుబడి"
]

# Overwrite file
with open("telugu_sample.txt", "w", encoding="utf-8") as f:
    for word in telugu_words_extended:
        f.write(word + "\n")

print(f"✅ Wrote {len(telugu_words_extended)} words to file")
# Out:
# ✅ Wrote 25 words to file

# %%
# Reload and retrain
data = io.read_corpus_file("telugu_sample.txt")
model = morfessor.BaselineModel()
model.load_data(data)
model.train_batch()

print("🔁 Model retrained on extended data!")
# Out:
# ..........................
# ..........................
# ..........................
# 🔁 Model retrained on extended data!

# %%
# Try segmenting again
for word in telugu_words_extended:
    segments = model.viterbi_segment(word)[0]
    print(f"{word} ➝ {' + '.join(segments)}")
# Out:
# చదువుతాడు ➝ చదువుతాడు
# చదువుతున్నారు ➝ చదువుతున్నారు
# చదువుతున్నాను ➝ చదువుతున్నాను
# చదువుతుంది ➝ చదువుతుంది
# చదువుతున్నవి ➝ చదువుతున్నవి
# పాటలకోసం ➝ పాట + లకోసం
# పాటలు ➝ పాట + లు
# పాటలతో ➝ పాట + లతో
# పాటకులకు ➝ పాట + కు + లకు
# పాటగా ➝ పాట + గా
# ఆడుతుంది ➝ ఆడుతుంది
# ఆడతాడు ➝ ఆడతాడు
# ఆడారు ➝ ఆడారు
# ఆడతానని ➝ ఆడతానని
# ఆడుతున్నాము ➝ ఆడుతున్నాము
# పరీక్ష ➝ పరీక్ష
# పరీక్షలు ➝ పరీక్ష + లు
# పరీక్షలకి ➝ పరీక్ష + లకి
# పరీక్షలకు ➝ పరీక్ష + లకు
# పరీక్షకు ➝ పరీక్ష + కు
# తెలుగునాడు ➝ తెలుగునాడు
# తెలుగులో ➝ తెలుగులో
# తెలుగువారు ➝ తెలుగువారు
# తెలుగుదేశం ➝ తెలుగుదేశం
# తెలుగుబడి ➝ తెలుగుబడి

# %%
import shutil
shutil.copy("telugu_500.txt", "telugu_sample.txt")

data = io.read_corpus_file("telugu_sample.txt")
model = morfessor.BaselineModel()
model.load_data(data)
model.train_batch()

print("✅ Morfessor trained on 500-word dataset!")
# Out:
# .......................................................
# ......................................................
# ✅ Morfessor trained on 500-word dataset!

# %% [markdown]
# ## 🔍 Step: Segment Sample Telugu Words using Trained Model
# Let’s now test how well the model segments new and existing Telugu words.

# %%
test_words = [
    "చదువుతున్నాను", "పరీక్షలకు", "తెలుగువారు", "పాఠశాలలో", "శిక్షణకోసం",
    "విద్యార్థులు", "తెలుగునాడు", "ఆడతాడు", "విద్యార్థికి", "శిక్షణలో"
]

for word in test_words:
    segments = model.viterbi_segment(word)[0]
    print(f"{word} ➝ {' + '.join(segments)}")
# Out:
# చదువుతున్నాను ➝ చదువుతున్నాను
# పరీక్షలకు ➝ పరీక్ష + లకు
# తెలుగువారు ➝ తెలుగువారు
# పాఠశాలలో ➝ పాఠశాలలో
# శిక్షణకోసం ➝ శిక్షణకోసం
# విద్యార్థులు ➝ విద్యార్థు + లు
# తెలుగునాడు ➝ తెలుగునాడు
# ఆడతాడు ➝ ఆడతాడు
# విద్యార్థికి ➝ విద్యార్థికి
# శిక్షణలో ➝ శిక్షణలో

# %%
import shutil
shutil.copy("telugu_10000.txt", "telugu_sample.txt")

data = io.read_corpus_file("telugu_sample.txt")
model = morfessor.BaselineModel()
model.load_data(data)
model.train_batch()

print("📈 Morfessor trained on 10,000 words!")
# Out:
# ...........................................................
# ...........................................................
# ...........................................................
# ...........................................................
# 📈 Morfessor trained on 10,000 words!

# %%
test_words = [
    "తెలుగులో", "పరీక్షలకి", "శిక్షణలో", "ఆడుతున్నాము", "తెలుగువారు",
    "విద్యార్థులకు", "గురుత్వాకర్షణ", "పాఠశాలలో", "సాహిత్యాన్ని", "అధ్యాపకుడు"
]

for word in test_words:
    segments = model.viterbi_segment(word)[0]
    print(f"{word} ➝ {' + '.join(segments)}")
# Out:
# తెలుగులో ➝ తెలుగు + లో
# పరీక్షలకి ➝ పరీక్ష + ల + కి
# శిక్షణలో ➝ శిక్షణ + లో
# ఆడుతున్నాము ➝ ఆడుతున్నాము
# తెలుగువారు ➝ తెలుగు + వారు
# విద్యార్థులకు ➝ విద్యార్థుల + కు
# గురుత్వాకర్షణ ➝ గురుత్వాకర్షణ
# పాఠశాలలో ➝ పాఠశాల + లో
# సాహిత్యాన్ని ➝ సాహిత్యాన్ + ని
# అధ్యాపకుడు ➝ అధ్యాపకుడు

# %%
test_words = ["తెలుగులో", "పరీక్షలకి", "శిక్షణలో", "ఆడుతున్నాము", "విద్యార్థులకు"]
for word in test_words:
    segments = model.viterbi_segment(word)[0]
    print(f"{word} → {' + '.join(segments)}")
# Out:
# తెలుగులో → తెలుగు + లో
# పరీక్షలకి → పరీక్ష + ల + కి
# శిక్షణలో → శిక్షణ + లో
# ఆడుతున్నాము → ఆడుతున్నాము
# విద్యార్థులకు → విద్యార్థుల + కు

# %%
test_words_file = []
with open("telugu_500.txt", "r", encoding="utf-8") as f:
    for line in f:
        word = line.strip()
        if word:
            test_words_file.append(word)

print(f"✅ Loaded {len(test_words_file)} words for testing.")
# Out:
# ✅ Loaded 500 words for testing.

# %%
split_count = 0
for word in test_words_file:
    segments = model.viterbi_segment(word)[0]
    if len(segments) > 1:
        split_count += 1
    print(f"{word} ➝ {' + '.join(segments)}")

print(f"\n📊 {split_count} out of {len(test_words_file)} words were segmented.")
# Out:
# చదువు ➝ చదువు
# మాచదువు ➝ మాచదువు
# అచదువు ➝ అచదువు
# ఉపచదువు ➝ ఉపచదువు
# సహచదువు ➝ సహచదువు
# చదువుతాడు ➝ చదువుతాడు
# మాచదువుతాడు ➝ మాచదువు + తాడు
# అచదువుతాడు ➝ అచదువు + తాడు
# ఉపచదువుతాడు ➝ ఉపచదువు + తాడు
# సహచదువుతాడు ➝ సహచదువు + తాడు
# చదువుతుంది ➝ చదువుతుంది
# మాచదువుతుంది ➝ మాచదువు + తుంది
# అచదువుతుంది ➝ అచదువు + తుంది
# ఉపచదువుతుంది ➝ ఉపచదువు + తుంది
# సహచదువుతుంది ➝ సహచదువు + తుంది
# చదువుతున్నారు ➝ చదువుతున్నారు
# మాచదువుతున్నారు ➝ మాచదువు + తున్నారు
# అచదువుతున్నారు ➝ అచదువు + తున్నారు
# ఉపచదువుతున్నారు ➝ ఉపచదువు + తున్నారు
# సహచదువుతున్నారు ➝ సహచదువు + తున్నారు
# చదువునాడు ➝ చదువునాడు
# మాచదువునాడు ➝ మాచదువు + నాడు
# అచదువునాడు ➝ అచదువు + నాడు
# ఉపచదువునాడు ➝ ఉపచదువు + నాడు
# సహచదువునాడు ➝ సహచదువు + నాడు
# చదువులు ➝ చదువులు
# మాచదువులు ➝ మాచదువు + లు
# అచదువులు ➝ అచదువు + లు
# ఉపచదువులు ➝ ఉపచదువు + లు
# సహచదువులు ➝ సహచదువు + లు
# ఉపఆడుగా ➝ ఉపఆడుగా
# సహఆడుగా ➝ సహఆడుగా
# ఆడులో ➝ ఆడులో
# మాఆడులో ➝ మాఆడులో
# అఆడులో ➝ అఆడులో
# ఉపఆడులో ➝ ఉపఆడులో
# సహఆడులో ➝ సహఆడులో
# ఆడుతో ➝ ఆడుతో
# మాఆడుతో ➝ మాఆడుతో
# అఆడుతో ➝ అఆడుతో
# ఉపఆడుతో ➝ ఉపఆడుతో
# సహఆడుతో ➝ సహఆడుతో
# ఆడుకి ➝ ఆడుకి
# మాఆడుకి ➝ మాఆడుకి
# అఆడుకి ➝ అఆడుకి
# ఉపఆడుకి ➝ ఉపఆడుకి
# సహఆడుకి ➝ సహఆడుకి
# ఆడుతోటి ➝ ఆడుతో + టి
# మాఆడుతోటి ➝ మాఆడుతో + టి
# అఆడుతోటి ➝ అఆడుతో + టి
# ఉపఆడుతోటి ➝ ఉపఆడుతో + టి
# సహఆడుతోటి ➝ సహఆడుతో + టి
# పరీక్ష ➝ పరీక్ష
# మాపరీక్ష ➝ మాపరీక్ష
# అపరీక్ష ➝ అపరీక్ష
# ఉపపరీక్ష ➝ ఉపపరీక్ష
# సహపరీక్ష ➝ సహపరీక్ష
# పరీక్షతాడు ➝ పరీక్ష + తాడు
# మాపరీక్షతాడు ➝ మాపరీక్ష + తాడు
# అపరీక్షతాడు ➝ అపరీక్ష + తాడు
# ఉపపరీక్షతాడు ➝ ఉపపరీక్ష + తాడు
# సహపరీక్షతాడు ➝ సహపరీక్ష + తాడు
# పరీక్షతుంది ➝ పరీక్ష + తుంది
# మాపరీక్షతుంది ➝ మాపరీక్ష + తుంది
# అపరీక్షతుంది ➝ అపరీక్ష + తుంది
# ఉపపరీక్షతుంది ➝ ఉపపరీక్ష + తుంది
# సహపరీక్షతుంది ➝ సహపరీక్ష + తుంది
# పరీక్షతున్నారు ➝ పరీక్ష + తున్నారు
# మాపరీక్షతున్నారు ➝ మాపరీక్ష + తున్నారు
# అపరీక్షతున్నారు ➝ అపరీక్ష + తున్నారు
# ఉపపరీక్షతున్నారు ➝ ఉపపరీక్ష + తున్నారు
# సహపరీక్షతున్నారు ➝ సహపరీక్ష + తున్నారు
# పరీక్షనాడు ➝ పరీక్ష + నాడు
# మాపరీక్షనాడు ➝ మాపరీక్ష + నాడు
# అపరీక్షనాడు ➝ అపరీక్ష + నాడు
# ఉపపరీక్షనాడు ➝ ఉపపరీక్ష + నాడు
# సహపరీక్షనాడు ➝ సహపరీక్ష + నాడు
# పరీక్షలు ➝ పరీక్ష + లు
# మాపరీక్షలు ➝ మాపరీక్ష + లు
# అపరీక్షలు ➝ అపరీక్ష + లు
# ఉపపరీక్షలు ➝ ఉపపరీక్ష + లు
# సహపరీక్షలు ➝ సహపరీక్ష + లు
# పరీక్షకు ➝ పరీక్ష + కు
# మాపరీక్షకు ➝ మాపరీక్ష + కు
# అపరీక్షకు ➝ అపరీక్ష + కు
# ఉపపరీక్షకు ➝ ఉపపరీక్ష + కు
# సహపరీక్షకు ➝ సహపరీక్ష + కు
# పరీక్షగా ➝ పరీక్ష + గా
# మాపరీక్షగా ➝ మాపరీక్ష + గా
# అపరీక్షగా ➝ అపరీక్ష + గా
# ఉపపరీక్షగా ➝ ఉపపరీక్ష + గా
# సహపరీక్షగా ➝ సహపరీక్ష + గా
# పరీక్షలో ➝ పరీక్ష + లో
# మాపరీక్షలో ➝ మాపరీక్ష + లో
# అపరీక్షలో ➝ అపరీక్ష + లో
# ఉపపరీక్షలో ➝ ఉపపరీక్ష + లో
# సహపరీక్షలో ➝ సహపరీక్ష + లో
# పరీక్షతో ➝ పరీక్ష + తో
# మాపరీక్షతో ➝ మాపరీక్ష + తో
# అపరీక్షతో ➝ అపరీక్ష + తో
# ఉపపరీక్షతో ➝ ఉపపరీక్ష + తో
# సహపరీక్షతో ➝ సహపరీక్ష + తో
# పరీక్షకి ➝ పరీక్ష + కి
# మాపరీక్షకి ➝ మాపరీక్ష + కి
# అపరీక్షకి ➝ అపరీక్ష + కి
# ఉపపరీక్షకి ➝ ఉపపరీక్ష + కి
# సహపరీక్షకి ➝ సహపరీక్ష + కి
# పరీక్షతోటి ➝ పరీక్ష + తో + టి
# మాపరీక్షతోటి ➝ మాపరీక్ష + తో + టి
# అపరీక్షతోటి ➝ అపరీక్ష + తో + టి
# ఉపపరీక్షతోటి ➝ ఉపపరీక్ష + తో + టి
# సహపరీక్షతోటి ➝ సహపరీక్ష + తో + టి
# తెలుగు ➝ తెలుగు
# మాతెలుగు ➝ మాతెలుగు
# అతెలుగు ➝ అతెలుగు
# ఉపతెలుగు ➝ ఉపతెలుగు
# సహతెలుగు ➝ సహతెలుగు
# తెలుగుతాడు ➝ తెలుగు + తాడు
# మాతెలుగుతాడు ➝ మాతెలుగు + తాడు
# అతెలుగుతాడు ➝ అతెలుగు + తాడు
# ఉపతెలుగుతాడు ➝ ఉపతెలుగు + తాడు
# సహతెలుగుతాడు ➝ సహతెలుగు + తాడు
# తెలుగుతుంది ➝ తెలుగు + తుంది
# మాతెలుగుతుంది ➝ మాతెలుగు + తుంది
# అతెలుగుతుంది ➝ అతెలుగు + తుంది
# ఉపతెలుగుతుంది ➝ ఉపతెలుగు + తుంది
# సహతెలుగుతుంది ➝ సహతెలుగు + తుంది
# తెలుగుతున్నారు ➝ తెలుగు + తున్నారు
# మాతెలుగుతున్నారు ➝ మాతెలుగు + తున్నారు
# అతెలుగుతున్నారు ➝ అతెలుగు + తున్నారు
# ఉపతెలుగుతున్నారు ➝ ఉపతెలుగు + తున్నారు
# సహతెలుగుతున్నారు ➝ సహతెలుగు + తున్నారు
# తెలుగునాడు ➝ తెలుగు + నాడు
# మాతెలుగునాడు ➝ మాతెలుగు + నాడు
# అతెలుగునాడు ➝ అతెలుగు + నాడు
# ఉపతెలుగునాడు ➝ ఉపతెలుగు + నాడు
# సహతెలుగునాడు ➝ సహతెలుగు + నాడు
# తెలుగులు ➝ తెలుగు + లు
# మాతెలుగులు ➝ మాతెలుగు + లు
# అతెలుగులు ➝ అతెలుగు + లు
# విద్యలు ➝ విద్యలు
# మావిద్యలు ➝ మావిద్య + లు
# అవిద్యలు ➝ అవిద్య + లు
# ఉపవిద్యలు ➝ ఉపవిద్య + లు
# సహవిద్యలు ➝ సహవిద్య + లు
# విద్యకు ➝ విద్యకు
# మావిద్యకు ➝ మావిద్య + కు
# అవిద్యకు ➝ అవిద్య + కు
# ఉపవిద్యకు ➝ ఉపవిద్య + కు
# సహవిద్యకు ➝ సహవిద్య + కు
# విద్యగా ➝ విద్యగా
# మావిద్యగా ➝ మావిద్య + గా
# అవిద్యగా ➝ అవిద్య + గా
# ఉపవిద్యగా ➝ ఉపవిద్య + గా
# సహవిద్యగా ➝ సహవిద్య + గా
# విద్యలో ➝ విద్యలో
# మావిద్యలో ➝ మావిద్య + లో
# అవిద్యలో ➝ అవిద్య + లో
# ఉపవిద్యలో ➝ ఉపవిద్య + లో
# సహవిద్యలో ➝ సహవిద్య + లో
# విద్యతో ➝ విద్యతో
# మావిద్యతో ➝ మావిద్య + తో
# అవిద్యతో ➝ అవిద్య + తో
# ఉపవిద్యతో ➝ ఉపవిద్య + తో
# సహవిద్యతో ➝ సహవిద్య + తో
# విద్యకి ➝ విద్యకి
# మావిద్యకి ➝ మావిద్య + కి
# అవిద్యకి ➝ అవిద్య + కి
# ఉపవిద్యకి ➝ ఉపవిద్య + కి
# సహవిద్యకి ➝ సహవిద్య + కి
# విద్యతోటి ➝ విద్యతో + టి
# మావిద్యతోటి ➝ మావిద్య + తో + టి
# అవిద్యతోటి ➝ అవిద్య + తో + టి
# ఉపవిద్యతోటి ➝ ఉపవిద్య + తో + టి
# సహవిద్యతోటి ➝ సహవిద్య + తో + టి
# శిక్షణ ➝ శిక్షణ
# మాశిక్షణ ➝ మా + శిక్షణ
# అశిక్షణ ➝ అశిక్షణ
# ఉపశిక్షణ ➝ ఉపశిక్షణ
# సహశిక్షణ ➝ సహశిక్షణ
# శిక్షణతాడు ➝ శిక్షణ + తాడు
# మాశిక్షణతాడు ➝ మా + శిక్షణ + తాడు
# అశిక్షణతాడు ➝ అశిక్షణ + తాడు
# ఉపశిక్షణతాడు ➝ ఉపశిక్షణ + తాడు
# సహశిక్షణతాడు ➝ సహశిక్షణ + తాడు
# శిక్షణతుంది ➝ శిక్షణ + తుంది
# మాశిక్షణతుంది ➝ మా + శిక్షణ + తుంది
# అశిక్షణతుంది ➝ అశిక్షణ + తుంది
# ఉపశిక్షణతుంది ➝ ఉపశిక్షణ + తుంది
# సహశిక్షణతుంది ➝ సహశిక్షణ + తుంది
# శిక్షణతున్నారు ➝ శిక్షణ + తున్నారు
# మాశిక్షణతున్నారు ➝ మా + శిక్షణ + తున్నారు
# అశిక్షణతున్నారు ➝ అశిక్షణ + తున్నారు
# ఉపశిక్షణతున్నారు ➝ ఉపశిక్షణ + తున్నారు
# సహశిక్షణతున్నారు ➝ సహశిక్షణ + తున్నారు
# శిక్షణనాడు ➝ శిక్షణ + నాడు
# మాశిక్షణనాడు ➝ మా + శిక్షణ + నాడు
# అశిక్షణనాడు ➝ అశిక్షణ + నాడు
# ఉపశిక్షణనాడు ➝ ఉపశిక్షణ + నాడు
# సహశిక్షణనాడు ➝ సహశిక్షణ + నాడు
# శిక్షణలు ➝ శిక్షణ + లు
# మాశిక్షణలు ➝ మా + శిక్షణ + లు
# అశిక్షణలు ➝ అశిక్షణ + లు
# ఉపశిక్షణలు ➝ ఉపశిక్షణ + లు
# సహశిక్షణలు ➝ సహశిక్షణ + లు
# శిక్షణకు ➝ శిక్షణ + కు
# మాశిక్షణకు ➝ మా + శిక్షణ + కు
# అశిక్షణకు ➝ అశిక్షణ + కు
# ఉపశిక్షణకు ➝ ఉపశిక్షణ + కు
# సహశిక్షణకు ➝ సహశిక్షణ + కు
# శిక్షణగా ➝ శిక్షణ + గా
# మాశిక్షణగా ➝ మా + శిక్షణ + గా
# అశిక్షణగా ➝ అశిక్షణ + గా
# ఉపశిక్షణగా ➝ ఉపశిక్షణ + గా
# సహశిక్షణగా ➝ సహశిక్షణ + గా
# శిక్షణలో ➝ శిక్షణ + లో
# మాశిక్షణలో ➝ మా + శిక్షణ + లో
# అశిక్షణలో ➝ అశిక్షణ + లో
# ఉపశిక్షణలో ➝ ఉపశిక్షణ + లో
# సహశిక్షణలో ➝ సహశిక్షణ + లో
# శిక్షణతో ➝ శిక్షణ + తో
# మాశిక్షణతో ➝ మా + శిక్షణ + తో
# అశిక్షణతో ➝ అశిక్షణ + తో
# ఉపశిక్షణతో ➝ ఉపశిక్షణ + తో
# సహశిక్షణతో ➝ సహశిక్షణ + తో
# శిక్షణకి ➝ శిక్షణ + కి
# మాశిక్షణకి ➝ మా + శిక్షణ + కి
# అశిక్షణకి ➝ అశిక్షణ + కి
# ఉపశిక్షణకి ➝ ఉపశిక్షణ + కి
# సహశిక్షణకి ➝ సహశిక్షణ + కి
# శిక్షణతోటి ➝ శిక్షణ + తో + టి
# మాశిక్షణతోటి ➝ మా + శిక్షణ + తో + టి
# అశిక్షణతోటి ➝ అశిక్షణ + తో + టి
# ఉపశిక్షణతోటి ➝ ఉపశిక్షణ + తో + టి
# సహశిక్షణతోటి ➝ సహశిక్షణ + తో + టి
# విద్యార్థి ➝ విద్యార్థి
# మావిద్యార్థి ➝ మావిద్య + ార్థి
# అవిద్యార్థి ➝ అవిద్య + ార్థి
# ఉపవిద్యార్థి ➝ ఉపవిద్య + ార్థి
# సహవిద్యార్థి ➝ సహవిద్య + ార్థి
# విద్యార్థితాడు ➝ విద్యార్థి + తాడు
# మావిద్యార్థితాడు ➝ మావిద్య + ార్థి + తాడు
# అవిద్యార్థితాడు ➝ అవిద్య + ార్థి + తాడు
# ఉపవిద్యార్థితాడు ➝ ఉపవిద్య + ార్థి + తాడు
# సహవిద్యార్థితాడు ➝ సహవిద్య + ార్థి + తాడు
# విద్యార్థితుంది ➝ విద్యార్థి + తుంది
# మావిద్యార్థితుంది ➝ మావిద్య + ార్థి + తుంది
# అవిద్యార్థితుంది ➝ అవిద్య + ార్థి + తుంది
# ఉపవిద్యార్థితుంది ➝ ఉపవిద్య + ార్థి + తుంది
# సహవిద్యార్థితుంది ➝ సహవిద్య + ార్థి + తుంది
# విద్యార్థితున్నారు ➝ విద్యార్థి + తున్నారు
# మావిద్యార్థితున్నారు ➝ మావిద్య + ార్థి + తున్నారు
# అవిద్యార్థితున్నారు ➝ అవిద్య + ార్థి + తున్నారు
# ఉపవిద్యార్థితున్నారు ➝ ఉపవిద్య + ార్థి + తున్నారు
# సహవిద్యార్థితున్నారు ➝ సహవిద్య + ార్థి + తున్నారు
# విద్యార్థినాడు ➝ విద్యార్థి + నాడు
# మావిద్యార్థినాడు ➝ మావిద్య + ార్థి + నాడు
# అవిద్యార్థినాడు ➝ అవిద్య + ార్థి + నాడు
# ఉపవిద్యార్థినాడు ➝ ఉపవిద్య + ార్థి + నాడు
# సహవిద్యార్థినాడు ➝ సహవిద్య + ార్థి + నాడు
# విద్యార్థిలు ➝ విద్యార్థి + లు
# మావిద్యార్థిలు ➝ మావిద్య + ార్థి + లు
# అవిద్యార్థిలు ➝ అవిద్య + ార్థి + లు
# ఉపవిద్యార్థిలు ➝ ఉపవిద్య + ార్థి + లు
# సహవిద్యార్థిలు ➝ సహవిద్య + ార్థి + లు
# విద్యార్థికు ➝ విద్యార్థి + కు
# మావిద్యార్థికు ➝ మావిద్య + ార్థి + కు
# అవిద్యార్థికు ➝ అవిద్య + ార్థి + కు
# ఉపవిద్యార్థికు ➝ ఉపవిద్య + ార్థి + కు
# సహవిద్యార్థికు ➝ సహవిద్య + ార్థి + కు
# విద్యార్థిగా ➝ విద్యార్థి + గా
# మావిద్యార్థిగా ➝ మావిద్య + ార్థి + గా
# అవిద్యార్థిగా ➝ అవిద్య + ార్థి + గా
# ఉపవిద్యార్థిగా ➝ ఉపవిద్య + ార్థి + గా
# సహవిద్యార్థిగా ➝ సహవిద్య + ార్థి + గా
# విద్యార్థిలో ➝ విద్యార్థి + లో
# మావిద్యార్థిలో ➝ మావిద్య + ార్థి + లో
# అవిద్యార్థిలో ➝ అవిద్య + ార్థి + లో
# ఉపవిద్యార్థిలో ➝ ఉపవిద్య + ార్థి + లో
# సహవిద్యార్థిలో ➝ సహవిద్య + ార్థి + లో
# విద్యార్థితో ➝ విద్యార్థి + తో
# మావిద్యార్థితో ➝ మావిద్య + ార్థి + తో
# అవిద్యార్థితో ➝ అవిద్య + ార్థి + తో
# ఉపవిద్యార్థితో ➝ ఉపవిద్య + ార్థి + తో
# సహవిద్యార్థితో ➝ సహవిద్య + ార్థి + తో
# విద్యార్థికి ➝ విద్యార్థి + కి
# మావిద్యార్థికి ➝ మావిద్య + ార్థి + కి
# అవిద్యార్థికి ➝ అవిద్య + ార్థి + కి
# ఉపవిద్యార్థికి ➝ ఉపవిద్య + ార్థి + కి
# సహవిద్యార్థికి ➝ సహవిద్య + ార్థి + కి
# విద్యార్థితోటి ➝ విద్యార్థితోటి
# మావిద్యార్థితోటి ➝ మావిద్య + ార్థితోటి
# అవిద్యార్థితోటి ➝ అవిద్య + ార్థితోటి
# ఉపవిద్యార్థితోటి ➝ ఉపవిద్య + ార్థితోటి
# సహపాఠంతాడు ➝ సహపాఠం + తాడు
# పాఠంతుంది ➝ పాఠం + తుంది
# మాపాఠంతుంది ➝ మాపాఠం + తుంది
# అపాఠంతుంది ➝ అపాఠం + తుంది
# ఉపపాఠంతుంది ➝ ఉపపాఠం + తుంది
# సహపాఠంతుంది ➝ సహపాఠం + తుంది
# పాఠంతున్నారు ➝ పాఠం + తున్నారు
# మాపాఠంతున్నారు ➝ మాపాఠం + తున్నారు
# అపాఠంతున్నారు ➝ అపాఠం + తున్నారు
# ఉపపాఠంతున్నారు ➝ ఉపపాఠం + తున్నారు
# సహపాఠంతున్నారు ➝ సహపాఠం + తున్నారు
# పాఠంనాడు ➝ పాఠం + నాడు
# మాపాఠంనాడు ➝ మాపాఠం + నాడు
# అపాఠంనాడు ➝ అపాఠం + నాడు
# ఉపపాఠంనాడు ➝ ఉపపాఠం + నాడు
#
# 📊 388 out of 500 words were segmented.

# %%
output_file = "Tested500words.txt"

with open(output_file, "w", encoding="utf-8") as f:
    for word in test_words_file:
        segments = model.viterbi_segment(word)[0]
        segmented_word = " + ".join(segments)
        f.write(f"{word} ➝ {segmented_word}\n")

print(f"✅ Segmentation results saved to {output_file}")
# Out:
# ✅ Segmentation results saved to Tested500words.txt

# %%
gold_dict = {
    "తెలుగులో": ["తెలుగు", "లో"],
    "పరీక్షలకు": ["పరీక్ష", "లకు"],
    "శిక్షణలో": ["శిక్షణ", "లో"],
    "ఆడుతున్నారు": ["ఆడు", "తున్నారు"],
    "విద్యార్థికి": ["విద్యార్థి", "కి"],
    "చదువుతున్నాను": ["చదువు", "తున్నాను"],
    "తెలుగునాడు": ["తెలుగు", "నాడు"],
    "ఆడుతుంది": ["ఆడు", "తుంది"],
    "పాఠశాలలో": ["పాఠశాల", "లో"],
    "గురువారు": ["గురు", "వారు"]
}

# %%
correct = 0
total = len(gold_dict)

print("🔍 Word-by-word comparison:\n")

for word, expected in gold_dict.items():
    predicted = model.viterbi_segment(word)[0]
    match = predicted == expected
    if match:
        correct += 1
    print(f"{word:15} → {' + '.join(predicted):25} | Expected: {' + '.join(expected):25} | {'✅' if match else '❌'}")

accuracy = (correct / total) * 100
print(f"\n📊 Overall Evaluation Accuracy: {accuracy:.2f}% ({correct}/{total} correct)")
# Out:
# 🔍 Word-by-word comparison:
#
# తెలుగులో        → తెలుగు + లో               | Expected: తెలుగు + లో               | ✅
# పరీక్షలకు       → పరీక్ష + ల + కు           | Expected: పరీక్ష + లకు              | ❌
# శిక్షణలో        → శిక్షణ + లో               | Expected: శిక్షణ + లో               | ✅
# ఆడుతున్నారు     → ఆడుతున్నారు               | Expected: ఆడు + తున్నారు            | ❌
# విద్యార్థికి    → విద్యార్థి + కి           | Expected: విద్యార్థి + కి           | ✅
# చదువుతున్నాను   → చదువుతున్నాను             | Expected: చదువు + తున్నాను          | ❌
# తెలుగునాడు      → తెలుగు + నాడు             | Expected: తెలుగు + నాడు             | ✅
# ఆడుతుంది        → ఆడుతుంది                  | Expected: ఆడు + తుంది               | ❌
# పాఠశాలలో        → పాఠశాల + లో               | Expected: పాఠశాల + లో               | ✅
# గురువారు        → గురువారు                  | Expected: గురు + వారు               | ❌
#
# 📊 Overall Evaluation Accuracy: 50.00% (5/10 correct)

# %%
with open("mixed_telugu_2000.txt", "r", encoding="utf-8") as f:
    train_words = [line.strip() for line in f if line.strip()]

# %%
# Step 2: Initialize and train the Morfessor model
io = morfessor.MorfessorIO()
model = morfessor.BaselineModel()

# Convert words into (count, word) pairs
train_data = [(1, word) for word in train_words]

model.load_data(train_data)
model.train_batch()

print("✅ Morfessor trained on 2000-word mixed dataset.")
# Out:
# ..........................................................
# ..........................................................
# ..........................................................
# ..........................................................
# ..........................................................
# ..........................................................
# ✅ Morfessor trained on 2000-word mixed dataset.

# %%
# Load the 500 test words
with open("telugu_500.txt", "r", encoding="utf-8") as f:
    test_words = [line.strip() for line in f if line.strip()]

# Segment each test word using the trained model
segmented_results = []
for word in test_words:
    segments = model.viterbi_segment(word)[0]
    segmented_results.append(f"{word} ➝ {' + '.join(segments)}")

# Save to a file
with open("segmented_output_500_from_2000mix.txt", "w", encoding="utf-8") as f:
    for line in segmented_results:
        f.write(line + "\n")

print("✅ Segmentation complete. Results saved to segmented_output_500_from_2000mix.txt")
# Out:
# ✅ Segmentation complete. Results saved to segmented_output_500_from_2000mix.txt

# %%
# Count how many words got split (i.e., more than one segment)
split_count = 0

for word in test_words:
    segments = model.viterbi_segment(word)[0]
    if len(segments) > 1:
        split_count += 1

print(f"🔍 {split_count} out of {len(test_words)} words were segmented into multiple morphemes.")
# Out:
# 🔍 459 out of 500 words were segmented into multiple morphemes.

# %%
correct = 0
total = len(gold_dict)

print("🔍 Word-by-word comparison:\n")

for word, expected in gold_dict.items():
    predicted = model.viterbi_segment(word)[0]
    match = predicted == expected
    if match:
        correct += 1
    print(f"{word:15} → {' + '.join(predicted):25} | Expected: {' + '.join(expected):25} | {'✅' if match else '❌'}")

accuracy = (correct / total) * 100
print(f"\n📊 Overall Evaluation Accuracy: {accuracy:.2f}% ({correct}/{total} correct)")
# Out:
# 🔍 Word-by-word comparison:
#
# తెలుగులో        → తెలుగు + లో               | Expected: తెలుగు + లో               | ✅
# పరీక్షలకు       → పరీక్ష + ల + కు           | Expected: పరీక్ష + లకు              | ❌
# శిక్షణలో        → శిక్షణ + లో               | Expected: శిక్షణ + లో               | ✅
# ఆడుతున్నారు     → ఆడు + తున్నారు            | Expected: ఆడు + తున్నారు            | ✅
# విద్యార్థికి    → విద్యార్థి + కి           | Expected: విద్యార్థి + కి           | ✅
# చదువుతున్నాను   → చదువు + తున్నాను          | Expected: చదువు + తున్నాను          | ✅
# తెలుగునాడు      → తెలుగు + నాడు             | Expected: తెలుగు + నాడు             | ✅
# ఆడుతుంది        → ఆడు + తుంది               | Expected: ఆడు + తుంది               | ✅
# పాఠశాలలో        → పాఠశాల + లో               | Expected: పాఠశాల + లో               | ✅
# గురువారు        → గురు + వారు               | Expected: గురు + వారు               | ✅
#
# 📊 Overall Evaluation Accuracy: 90.00% (9/10 correct)
